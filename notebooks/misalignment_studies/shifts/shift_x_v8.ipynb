# %% [markdown]
# # Embedding and Filtering Inference

# %% [markdown]
# Set default input and output directories according to local paths for data

# %%
import os
os.environ['TRKXINPUTDIR']="/global/cfs/cdirs/m3443/data/trackml-kaggle/train_10evts"
os.environ['TRKXOUTPUTDIR']= "/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/misaligned/new_mis/shift_x_v8_pre/"

# %% [markdown]
# Import necessary libraries and functions

# %%
import pkg_resources
import yaml
import pprint
import random
random.seed(1234)
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import tqdm
from os import listdir
from os.path import isfile, join
import matplotlib.cm as cm
import sys
import time
# %matplotlib widget

sys.path.append('/global/homes/c/caditi97/exatrkx-iml2020/exatrkx/src/')

# 3rd party
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from trackml.dataset import load_event
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import ModelCheckpoint


# local import
from exatrkx import config_dict # for accessing predefined configuration files
from exatrkx import outdir_dict # for accessing predefined output directories
from exatrkx.src import utils_dir
from exatrkx.src import utils_robust
from utils_robust import *


# for preprocessing
from exatrkx import FeatureStore
from exatrkx.src import utils_torch

# for embedding
from exatrkx import LayerlessEmbedding
from exatrkx.src import utils_torch
from torch_cluster import radius_graph
from utils_torch import build_edges
from embedding.embedding_base import *

# for filtering
from exatrkx import VanillaFilter

# for GNN
import tensorflow as tf
from graph_nets import utils_tf
from exatrkx import SegmentClassifier
import sonnet as snt

# for labeling
from exatrkx.scripts.tracks_from_gnn import prepare as prepare_labeling
from exatrkx.scripts.tracks_from_gnn import clustering as dbscan_clustering

# track efficiency
from trackml.score import _analyze_tracks
from exatrkx.scripts.eval_reco_trkx import make_cmp_plot, pt_configs, eta_configs
from functools import partial

# %%
noise_keep = ['0','0.2','0.4','0.6','0.8','1']
plt.rcParams.update({'axes.titlesize' : 16, 'axes.labelsize' : 16, 'lines.linewidth' : 2, 'lines.markersize' : 10,
                    'xtick.labelsize' : 14, 'xtick.major.width' : 2,
                    'ytick.labelsize' : 14, 'ytick.major.width' : 2,
                    'grid.alpha' : 0.5, "legend.frameon" : False, 'legend.fontsize' : 16})
noise_labels = [f'{float(n)*0.2*100:.0f}' for n in noise_keep]

# %% [markdown]
# ## Adding Noise

# %%
# noise_keep = ["0", "0.2", "0.4", "0.6", "0.8", "1"]
# plot_noise_dist(noise_keep)
misl = [0.02,0.1,0.4,0.6,0.8,1]

# %% [markdown]
# ## Embedding

# %% [markdown]
# Set checkpoint and other directory paths

# %%
embed_ckpt_dir = '/global/cfs/cdirs/m3443/data/lightning_models/embedding/checkpoints/epoch=10.ckpt'
filter_ckpt_dir = '/global/cfs/cdirs/m3443/data/lightning_models/filtering/checkpoints/epoch=92.ckpt'
gnn_ckpt_dir = '/global/cfs/cdirs/m3443/data/lightning_models/gnn'
plots_dir = '/global/homes/c/caditi97/exatrkx-iml2020/exatrkx/src/plots/run1' # needs to change...

# %% [markdown]
# Fixing some parameters

# %%
ckpt_idx = -1 # which GNN checkpoint to load
dbscan_epsilon, dbscan_minsamples = 0.25, 2 # hyperparameters for DBScan
min_hits = 5 # minimum number of hits associated with a particle to define "reconstructable particles"
frac_reco_matched, frac_truth_matched = 0.5, 0.5 # parameters for track matching

# %% [markdown]
# Load embedding model from checkpoint

# %%
emb_ckpt = torch.load(embed_ckpt_dir, map_location='cpu')
emb_ckpt['hyper_parameters']['train_split'] = [8,1,1]
emb_ckpt['hyper_parameters']['clustering'] = 'build_edges'
emb_ckpt['hyper_parameters']['knn_val'] = 500
emb_ckpt['hyper_parameters']['r_val'] = 1.7
emb_ckpt['hyper_parameters']
# Out:
# "adjacent":       False
# "clustering":     build_edges
# "emb_dim":        8
# "emb_hidden":     512
# "endcaps":        True
# "factor":         0.3
# "in_channels":    12
# "input_dir":      /global/cscratch1/sd/danieltm/ExaTrkX/trackml/feature_store_endcaps
# "knn":            20
# "knn_val":        500
# "layerless":      True
# "layerwise":      False
# "lr":             0.002
# "margin":         1
# "max_epochs":     100
# "nb_layer":       6
# "noise":          False
# "output_dir":     global/cscratch1/sd/danieltm/ExaTrkX/trackml_processed/embedding_processed/0_pt_cut_endcaps
# "overwrite":      True
# "patience":       5
# "project":        EmbeddingStudy
# "pt_min":         0
# "r_train":        1
# "r_val":          1.7
# "randomisation":  2
# "regime":         ['rp', 'hnm', 'ci']
# "train_split":    [8, 1, 1]
# "wandb_save_dir": /global/cscratch1/sd/danieltm/ExaTrkX/wandb_data
# "warmup":         500
# "weight":         4

# %%
emb_model = LayerlessEmbedding(emb_ckpt['hyper_parameters'])
emb_model.load_state_dict(emb_ckpt["state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# Put model in evaluation state

# %%
emb_model.eval()
# Out:
# LayerlessEmbedding(
#   (layers): ModuleList(
#     (0): Linear(in_features=12, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=512, bias=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#   )
#   (emb_layer): Linear(in_features=512, out_features=8, bias=True)
#   (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   (act): Tanh()
# )

# %% [markdown]
# Define embedding metrics (function gets metrics for one event)

# %%
def get_emb_metrics(data_path, emb_model,r_val=1.7,knn_val=500):
    data = torch.load(data_path)
    spatial = emb_model(torch.cat([data.cell_data, data.x], axis=-1))
    
    if(torch.cuda.is_available()):
        spatial = spatial.cuda()
        
    e_spatial = utils_torch.build_edges(spatial, r_val, knn_val)
    e_spatial_np = e_spatial.cpu().numpy()
    
    # remove R dist from out to in
    R_dist = torch.sqrt(data.x[:,0]**2 + data.x[:,2]**2)
    
    e_spatial_np = e_spatial_np[:, (R_dist[e_spatial_np[0]] <= R_dist[e_spatial_np[1]])]
    e_bidir = torch.cat([data.layerless_true_edges,torch.stack([data.layerless_true_edges[1],
                        data.layerless_true_edges[0]], axis=1).T], axis=-1)
    e_spatial_n, y_cluster = graph_intersection(torch.from_numpy(e_spatial_np), e_bidir)
    
    cluster_true = len(data.layerless_true_edges[0])
    cluster_true_positive = y_cluster.sum()
    cluster_positive = len(e_spatial_n[0])
    purity = cluster_true_positive/cluster_positive
    eff = cluster_true_positive/cluster_true
    
    print("-----------")
    print(f"cluster true = {cluster_true}")
    print(f"cluste true positive = {cluster_true_positive}")
    print(f"cluster positive = {cluster_positive}")
    print(f"purity = {purity}")
    print(f"efficiency = {eff}")
    
    return purity, eff

# %%
def get_lvl_emb(mypath,emb_model,r_val=1.7,knn_val=500):
    events = [f for f in listdir(mypath) if isfile(join(mypath, f))][:5]
    p_lvl = []
    e_lvl = []
    for evt in events:
        data_path = join(mypath,evt)
        p, e = get_emb_metrics(data_path, emb_model,r_val,knn_val) 
        p_lvl.append(p)
        e_lvl.append(e)
    
    return np.mean(p_lvl), np.mean(e_lvl)

# %% [markdown]
# Metrics for one event and all noise configurations

# %%
# %%time
p_all = []
e_all = []
misl = [0.02,0.1,0.4,0.6,0.8,1]
for i in misl:
    mypath = f"/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/misaligned/new_mis/shift_x_v8_pre/{i}/feature_store/"
    print(f"------ {i} ------")
    start = time.time()
    p,e = get_lvl_emb(mypath,emb_model)
    end = time.time()
    print(end-start)
    p_all.append(p)
    e_all.append(e)
# Out:
# ------ 0.02 ------
# -----------
# cluster true = 113355
# cluste true positive = 110455
# cluster positive = 8607573
# purity = 0.012832304762329636
# efficiency = 0.9744166556393631
# -----------
# cluster true = 103420
# cluste true positive = 100831
# cluster positive = 7614867
# purity = 0.013241334352917786
# efficiency = 0.9749661574163605
# -----------
# cluster true = 144774
# cluste true positive = 140785
# cluster positive = 13223635
# purity = 0.010646467480386444
# efficiency = 0.9724467100446212
# -----------
# cluster true = 109839
# cluste true positive = 106889
# cluster positive = 8318710
# purity = 0.012849227824987288
# efficiency = 0.9731425085807409
# -----------
# cluster true = 120157
# cluste true positive = 117349
# cluster positive = 9536643
# purity = 0.012305063742031656
# efficiency = 0.9766305749977113
# 519.9749431610107
# ------ 0.1 ------
# -----------
# cluster true = 113355
# cluste true positive = 110454
# cluster positive = 8607775
# purity = 0.012831887450589729
# efficiency = 0.9744078337964801
# -----------
# cluster true = 103420
# cluste true positive = 100831
# cluster positive = 7614980
# purity = 0.01324113786247633
# efficiency = 0.9749661574163605
# -----------
# cluster true = 144774
# cluste true positive = 140783
# cluster positive = 13223682
# purity = 0.010646278396591812
# efficiency = 0.9724328954093967
# -----------
# cluster true = 109839
# cluste true positive = 106889
# cluster positive = 8318843
# purity = 0.012849022394099756
# efficiency = 0.9731425085807409
# -----------
# cluster true = 120157
# cluste true positive = 117351
# cluster positive = 9536839
# purity = 0.012305020562893008
# efficiency = 0.9766472198873141
# 519.5531787872314
# ------ 0.4 ------
# -----------
# cluster true = 113355
# cluste true positive = 110456
# cluster positive = 8608322
# purity = 0.012831304405202314
# efficiency = 0.9744254774822461
# -----------
# cluster true = 103420
# cluste true positive = 100828
# cluster positive = 7615738
# purity = 0.013239426041179463
# efficiency = 0.9749371494875266
# -----------
# cluster true = 144774
# cluste true positive = 140782
# cluster positive = 13223635
# purity = 0.010646240613870542
# efficiency = 0.9724259880917845
# -----------
# cluster true = 109839
# cluste true positive = 106888
# cluster positive = 8319806
# purity = 0.012847414951742865
# efficiency = 0.9731334043463615
# -----------
# cluster true = 120157
# cluste true positive = 117349
# cluster positive = 9536775
# purity = 0.01230489342571257
# efficiency = 0.9766305749977113
# 522.7415904998779
# ------ 0.6 ------
# -----------
# cluster true = 113355
# cluste true positive = 110455
# cluster positive = 8609221
# purity = 0.012829848368394771
# efficiency = 0.9744166556393631
# -----------
# cluster true = 103420
# cluste true positive = 100823
# cluster positive = 7616157
# purity = 0.013238041180085968
# efficiency = 0.9748888029394701
# -----------
# cluster true = 144774
# cluste true positive = 140780
# cluster positive = 13224359
# purity = 0.010645506523227327
# efficiency = 0.9724121734565598
# -----------
# cluster true = 109839
# cluste true positive = 106890
# cluster positive = 8320818
# purity = 0.01284609277597467
# efficiency = 0.9731516128151203
# -----------
# cluster true = 120157
# cluste true positive = 117343
# cluster positive = 9537391
# purity = 0.012303469575694233
# efficiency = 0.976580640328903
# 522.3579454421997
# ------ 0.8 ------
# -----------
# cluster true = 113355
# cluste true positive = 110451
# cluster positive = 8610349
# purity = 0.012827703035033772
# efficiency = 0.9743813682678312
# -----------
# cluster true = 103420
# cluste true positive = 100825
# cluster positive = 7616850
# purity = 0.013237099325836795
# efficiency = 0.9749081415586928
# -----------
# cluster true = 144774
# cluste true positive = 140777
# cluster positive = 13226184
# purity = 0.010643810792288993
# efficiency = 0.9723914515037231
# -----------
# cluster true = 109839
# cluste true positive = 106893
# cluster positive = 8322123
# purity = 0.012844438852922505
# efficiency = 0.9731789255182586
# -----------
# cluster true = 120157
# cluste true positive = 117346
# cluster positive = 9538240
# purity = 0.012302688965679202
# efficiency = 0.9766056076633072
# 520.507716178894
# ------ 1 ------
# -----------
# cluster true = 113355
# cluste true positive = 110453
# cluster positive = 8611831
# purity = 0.012825727769158498
# efficiency = 0.9743990119535971
# -----------
# cluster true = 103420
# cluste true positive = 100826
# cluster positive = 7617993
# purity = 0.013235244506000466
# efficiency = 0.974917810868304
# -----------
# cluster true = 144774
# cluste true positive = 140774
# cluster positive = 13227211
# purity = 0.010642757569982063
# efficiency = 0.9723707295508862
# -----------
# cluster true = 109839
# cluste true positive = 106891
# cluster positive = 8323484
# purity = 0.012842098332861577
# efficiency = 0.9731607170494997
# -----------
# cluster true = 120157
# cluste true positive = 117345
# cluster positive = 9538867
# purity = 0.012301775462431754
# efficiency = 0.9765972852185058
# 520.0928421020508
# CPU times: user 9h 46s, sys: 3min 31s, total: 9h 4min 17s
# Wall time: 52min 5s

# %%
pf = [ round(elem, 3) for elem in p_all ]
ef = [ round(elem, 3) for elem in e_all ]
e_all
# Out:
# [0.9743205213357594,
#  0.9743193230180586,
#  0.974310518881126,
#  0.9742899770358833,
#  0.9742930989023625,
#  0.9742891109281586]

# %%
import matplotlib.ticker as ticker
x = np.arange(len(misl))
fig, (axn,axnn) = plt.subplots(1,2, figsize=(15,7))

# fig1.suptitle('Evt 1000')
fig.tight_layout(w_pad = 10)
axn.plot(misl, pf, label = 'True Positive / Positive')
axn.set_xlabel('Misalignment')
axn.set_ylabel('Purity')
axn.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0e'))
axn.set_xticks(misl)
axn.legend()

axnn.plot(misl, ef, label = 'True Positive / True')
axnn.set_xlabel('Misalignment')
axnn.set_ylabel('Efficiency')
axnn.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0e'))
axnn.set_xticks(misl)
axnn.legend()

# %%
fig2, ax = plt.subplots(figsize=(10,10))
# fig2.suptitle(f'Eventid 1000, All noise, rval=1.7, knn=500')
colors = cm.inferno_r(np.linspace(0,5))
for i,mis in enumerate(misl):
    ax.scatter(p_all[i],e_all[i], color = colors[i], label = mis)
ax.set_xlabel('Purity')
ax.set_ylabel('Efficiency')
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0e'))
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0e'))
ax.legend()

# %% [markdown]
# Average metrics for all events and all noise configurations

# %%
# p_avg = []
# e_avg = []
# for i in noise_keep:
#     data_path = f'/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/out{i}/feature_store/'
#     p, e = get_lvl_emb(data_path,emb_model)
#     p_avg.append(p)
#     e_avg.append(e)

# %%
# x = np.arange(len(noise_keep))
# fig2, (ax1,ax2) = plt.subplots(1,2, figsize=(15,7))
# fig2.tight_layout(w_pad = 10)
# fig2.suptitle('10 Events')
# ax1.plot(x, p_avg, label = 'True Positive / Positive')
# ax1.set_xlabel('noise_level')
# ax1.set_ylabel('Purity')
# ax1.set_xticks(x)
# ax1.set_xticklabels(noise_keep)
# ax1.legend()

# ax2.plot(x, e_avg, label = 'True Positive / True')
# ax2.set_xlabel('noise_level')
# ax2.set_ylabel('Efficiency')
# ax2.set_xticks(x)
# ax2.set_xticklabels(noise_keep)
# ax2.legend()

# %% [markdown]
# Tuning Hyperparameters `r_val = 1.7` and `knn_val = 500` with a set level of noise for a specific event.
#
# * `r_val` defines the radius of the clustering method
# * `knn_val` defines the number of maximum neighbors in the embedding space

# %%
# noise_lvl = 1
# evtid = 1000
# set_event = f'/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/outtest/out{noise_lvl}/feature_store/{evtid}'

# %%
rvals = np.arange(1,2,0.1)
ogp_val = []
oge_val = []
for n in rvals:
    data_path = "/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/layerless_check/n0/feature_store/"
    print(f"------ {n} ------")
    start = time.time()
    opv,oev = get_lvl_emb(data_path,emb_model,r_val=n)
    end = time.time()
    print(end-start)
    ogp_val.append(opv)
    oge_val.append(oev)
# Out:
# ------ 1.0 ------
# -----------
# cluster true = 98107
# cluste true positive = 85829
# cluster positive = 486295
# purity = 0.17649574846543764
# efficiency = 0.8748509280683335
# -----------
# cluster true = 104909
# cluste true positive = 91255
# cluster positive = 558842
# purity = 0.16329302378847688
# efficiency = 0.8698491073215835
# -----------
# cluster true = 116478
# cluste true positive = 101816
# cluster positive = 660364
# purity = 0.15418163315989364
# efficiency = 0.8741221518226618
# -----------
# cluster true = 118662
# cluste true positive = 103575
# cluster positive = 658044
# purity = 0.15739828947608367
# efficiency = 0.8728573595590838
# -----------
# cluster true = 103195
# cluste true positive = 90518
# cluster positive = 528838
# purity = 0.17116394812778205
# efficiency = 0.877154900915742
# 336.4001886844635
# ------ 1.1 ------
# -----------
# cluster true = 98107
# cluste true positive = 88958
# cluster positive = 709387
# purity = 0.1254012266929053
# efficiency = 0.9067446767305085
# -----------
# cluster true = 104909
# cluste true positive = 94608
# cluster positive = 826609
# purity = 0.1144531453202179
# efficiency = 0.9018101402167593
# -----------
# cluster true = 116478
# cluste true positive = 105450
# cluster positive = 980460
# purity = 0.10755155743222569
# efficiency = 0.9053211765311905
# -----------
# cluster true = 118662
# cluste true positive = 107374
# cluster positive = 970929
# purity = 0.11058893080750498
# efficiency = 0.9048726635317119
# -----------
# cluster true = 103195
# cluste true positive = 93610
# cluster positive = 771764
# purity = 0.12129355606117932
# efficiency = 0.9071175929066331
# 396.76672172546387
# ------ 1.2000000000000002 ------
# -----------
# cluster true = 98107
# cluste true positive = 91124
# cluster positive = 1052597
# purity = 0.08657064384565033
# efficiency = 0.9288226120460313
# -----------
# cluster true = 104909
# cluste true positive = 96960
# cluster positive = 1240853
# purity = 0.07813979576952307
# efficiency = 0.9242295703895758
# -----------
# cluster true = 116478
# cluste true positive = 108035
# cluster positive = 1476463
# purity = 0.07317149159850264
# efficiency = 0.9275142086917701
# -----------
# cluster true = 118662
# cluste true positive = 110068
# cluster positive = 1459441
# purity = 0.07541791685994843
# efficiency = 0.927575803542836
# -----------
# cluster true = 103195
# cluste true positive = 95734
# cluster positive = 1145883
# purity = 0.08354605138569994
# efficiency = 0.927699985464412
# 430.36701130867004
# ------ 1.3000000000000003 ------
# -----------
# cluster true = 98107
# cluste true positive = 92667
# cluster positive = 1576424
# purity = 0.058783043140677886
# efficiency = 0.9445503378963784
# -----------
# cluster true = 104909
# cluste true positive = 98684
# cluster positive = 1873596
# purity = 0.052670906641559864
# efficiency = 0.9406628601931197
# -----------
# cluster true = 116478
# cluste true positive = 109923
# cluster positive = 2234023
# purity = 0.0492040592240993
# efficiency = 0.9437232782156287
# -----------
# cluster true = 118662
# cluste true positive = 111938
# cluster positive = 2204416
# purity = 0.050778981825571945
# efficiency = 0.9433348502469199
# -----------
# cluster true = 103195
# cluste true positive = 97329
# cluster positive = 1713562
# purity = 0.056799228741066854
# efficiency = 0.9431561606666989
# 392.13595032691956
# ------ 1.4000000000000004 ------
# -----------
# cluster true = 98107
# cluste true positive = 93778
# cluster positive = 2352681
# purity = 0.03986005752586092
# efficiency = 0.955874708226732
# -----------
# cluster true = 104909
# cluste true positive = 99931
# cluster positive = 2813063
# purity = 0.035523911124635314
# efficiency = 0.9525493522957992
# -----------
# cluster true = 116478
# cluste true positive = 111322
# cluster positive = 3355748
# purity = 0.033173527928795604
# efficiency = 0.9557341300503099
# -----------
# cluster true = 118662
# cluste true positive = 113359
# cluster positive = 3307042
# purity = 0.034278064808369535
# efficiency = 0.955310040282483
# -----------
# cluster true = 103195
# cluste true positive = 98526
# cluster positive = 2556862
# purity = 0.03853395294701083
# efficiency = 0.9547555598623965
# 404.58946347236633
# ------ 1.5000000000000004 ------
# -----------
# cluster true = 98107
# cluste true positive = 94664
# cluster positive = 3455551
# purity = 0.027394762803385046
# efficiency = 0.9649056642237557
# -----------
# cluster true = 104909
# cluste true positive = 100918
# cluster positive = 4136759
# purity = 0.024395426467918483
# efficiency = 0.9619575060290347
# -----------
# cluster true = 116478
# cluste true positive = 112335
# cluster positive = 4910033
# purity = 0.02287866497027617
# efficiency = 0.9644310513573379
# -----------
# cluster true = 118662
# cluste true positive = 114431
# cluster positive = 4852067
# purity = 0.02358396947115528
# efficiency = 0.9643441034197974
# -----------
# cluster true = 103195
# cluste true positive = 99514
# cluster positive = 3753320
# purity = 0.026513593298732856
# efficiency = 0.9643296671350357
# 441.59871459007263
# ------ 1.6000000000000005 ------
# -----------
# cluster true = 98107
# cluste true positive = 95302
# cluster positive = 4898695
# purity = 0.019454569022974485
# efficiency = 0.9714087679778202
# -----------
# cluster true = 104909
# cluste true positive = 101729
# cluster positive = 5838306
# purity = 0.017424403585560605
# efficiency = 0.9696880153275697
# -----------
# cluster true = 116478
# cluste true positive = 113123
# cluster positive = 6872137
# purity = 0.01646110955005699
# efficiency = 0.9711962774086094
# -----------
# cluster true = 118662
# cluste true positive = 115228
# cluster positive = 6831738
# purity = 0.016866571873804293
# efficiency = 0.9710606596888641
# -----------
# cluster true = 103195
# cluste true positive = 100181
# cluster positive = 5316624
# purity = 0.01884297253294572
# efficiency = 0.9707931585832646
# 432.34584307670593
# ------ 1.7000000000000006 ------
# -----------
# cluster true = 98107
# cluste true positive = 95730
# cluster positive = 6626809
# purity = 0.014445866781432812
# efficiency = 0.9757713516874433
# -----------
# cluster true = 104909
# cluste true positive = 102231
# cluster positive = 7849250
# purity = 0.01302430168487435
# efficiency = 0.9744731147947269
# -----------
# cluster true = 116478
# cluste true positive = 113666
# cluster positive = 9160203
# purity = 0.012408676969276772
# efficiency = 0.9758581019591682
# -----------
# cluster true = 118662
# cluste true positive = 115783
# cluster positive = 9178018
# purity = 0.01261525091800866
# efficiency = 0.975737809913873
# -----------
# cluster true = 103195
# cluste true positive = 100664
# cluster positive = 7188799
# purity = 0.014002895337593944
# efficiency = 0.9754736179078444
# 437.9897096157074
# ------ 1.8000000000000007 ------
# -----------
# cluster true = 98107
# cluste true positive = 96008
# cluster positive = 8586004
# purity = 0.011181918853054343
# efficiency = 0.9786049925081799
# -----------
# cluster true = 104909
# cluste true positive = 102567
# cluster positive = 10105387
# purity = 0.010149734987883196
# efficiency = 0.9776758905337006
# -----------
# cluster true = 116478
# cluste true positive = 113957
# cluster positive = 11699167
# purity = 0.009740608027904893
# efficiency = 0.9783564278232799
# -----------
# cluster true = 118662
# cluste true positive = 116121
# cluster positive = 11817231
# purity = 0.009826413649695094
# efficiency = 0.978586236537392
# -----------
# cluster true = 103195
# cluste true positive = 101009
# cluster positive = 9324862
# purity = 0.01083222464847201
# efficiency = 0.978816803139687
# 438.3040828704834
# ------ 1.9000000000000008 ------
# -----------
# cluster true = 98107
# cluste true positive = 96206
# cluster positive = 10743628
# purity = 0.008954703197095059
# efficiency = 0.9806231971215101
# -----------
# cluster true = 104909
# cluste true positive = 102758
# cluster positive = 12529446
# purity = 0.008201320313763274
# efficiency = 0.9794965160281768
# -----------
# cluster true = 116478
# cluste true positive = 114140
# cluster positive = 14411607
# purity = 0.007920005034830606
# efficiency = 0.9799275399646286
# -----------
# cluster true = 118662
# cluste true positive = 116358
# cluster positive = 14653898
# purity = 0.007940412851242721
# efficiency = 0.9805835060929362
# -----------
# cluster true = 103195
# cluste true positive = 101195
# cluster positive = 11660333
# purity = 0.008678568613778012
# efficiency = 0.9806192160472891
# 438.9350497722626

# %%
oge_val
# Out:
# [0.873766889537481,
#  0.9051732499833607,
#  0.927168436026925,
#  0.943085497443749,
#  0.954844758143544,
#  0.9639935984329921,
#  0.9708293757972255,
#  0.9754627992526113,
#  0.9784080701084479,
#  0.9802499950509083]

# %%
# %%time
rvals = np.arange(1,2,0.1)
p_val = []
e_val = []
for n in rvals:
    data_path = f"/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/misaligned/new_mis/shift_x_v8_pre/1/feature_store/"
    print(f"------ {n} ------")
    start = time.time()
    opv,oev = get_lvl_emb(data_path,emb_model,r_val=n)
    end = time.time()
    print(end-start)
    p_val.append(opv)
    e_val.append(oev)
# Out:
# ------ 1.0 ------
# -----------
# cluster true = 113355
# cluste true positive = 98485
# cluster positive = 622009
# purity = 0.15833372185933
# efficiency = 0.8688191963301134
# -----------
# cluster true = 103420
# cluste true positive = 90019
# cluster positive = 541469
# purity = 0.16624959138935008
# efficiency = 0.8704215818990524
# -----------
# cluster true = 144774
# cluste true positive = 125954
# cluster positive = 953710
# purity = 0.13206739994337902
# efficiency = 0.8700042825369196
# -----------
# cluster true = 109839
# cluste true positive = 95561
# cluster positive = 594814
# purity = 0.1606569448600739
# efficiency = 0.8700097415307859
# -----------
# cluster true = 120157
# cluste true positive = 105726
# cluster positive = 685404
# purity = 0.15425354973125338
# efficiency = 0.8798987990712152
# 511.0442626476288
# ------ 1.1 ------
# -----------
# cluster true = 113355
# cluste true positive = 102113
# cluster positive = 918892
# purity = 0.11112622593297145
# efficiency = 0.9008248423095585
# -----------
# cluster true = 103420
# cluste true positive = 93319
# cluster positive = 801308
# purity = 0.11645834061309758
# efficiency = 0.9023303036163218
# -----------
# cluster true = 144774
# cluste true positive = 130609
# cluster positive = 1435363
# purity = 0.09099370681841458
# efficiency = 0.9021578460220758
# -----------
# cluster true = 109839
# cluste true positive = 99047
# cluster positive = 878827
# purity = 0.1127036379173603
# efficiency = 0.9017471025774088
# -----------
# cluster true = 120157
# cluste true positive = 109329
# cluster positive = 1013619
# purity = 0.10786005392558742
# efficiency = 0.9098845676906048
# 476.26439785957336
# ------ 1.2000000000000002 ------
# -----------
# cluster true = 113355
# cluste true positive = 104751
# cluster positive = 1379249
# purity = 0.07594785278075242
# efficiency = 0.9240968638348551
# -----------
# cluster true = 103420
# cluste true positive = 95733
# cluster positive = 1206103
# purity = 0.07937381799066912
# efficiency = 0.925672017017985
# -----------
# cluster true = 144774
# cluste true positive = 133988
# cluster positive = 2190357
# purity = 0.06117176332442611
# efficiency = 0.9254976722339646
# -----------
# cluster true = 109839
# cluste true positive = 101466
# cluster positive = 1322157
# purity = 0.07674277714371289
# efficiency = 0.9237702455412012
# -----------
# cluster true = 120157
# cluste true positive = 111834
# cluster positive = 1522026
# purity = 0.07347706280970233
# efficiency = 0.9307322919180738
# 415.5706853866577
# ------ 1.3000000000000003 ------
# -----------
# cluster true = 113355
# cluste true positive = 106584
# cluster positive = 2079593
# purity = 0.051252336394669536
# efficiency = 0.9402673018393543
# -----------
# cluster true = 103420
# cluste true positive = 97514
# cluster positive = 1820421
# purity = 0.05356672989379929
# efficiency = 0.9428930574356991
# -----------
# cluster true = 144774
# cluste true positive = 136336
# cluster positive = 3340925
# purity = 0.04080786009862538
# efficiency = 0.9417160539875945
# -----------
# cluster true = 109839
# cluste true positive = 103232
# cluster positive = 1996836
# purity = 0.05169778589728951
# efficiency = 0.939848323455239
# -----------
# cluster true = 120157
# cluste true positive = 113718
# cluster positive = 2298902
# purity = 0.04946622344058164
# efficiency = 0.9464117779238829
# 394.81205582618713
# ------ 1.4000000000000004 ------
# -----------
# cluster true = 113355
# cluste true positive = 108057
# cluster positive = 3117957
# purity = 0.03465634708881489
# efficiency = 0.9532618764059813
# -----------
# cluster true = 103420
# cluste true positive = 98758
# cluster positive = 2731876
# purity = 0.036150249864927986
# efficiency = 0.9549216785921485
# -----------
# cluster true = 144774
# cluste true positive = 138061
# cluster positive = 5034006
# purity = 0.02742567251608361
# efficiency = 0.9536311768687747
# -----------
# cluster true = 109839
# cluste true positive = 104640
# cluster positive = 2997190
# purity = 0.03491270156379809
# efficiency = 0.9526670854614481
# -----------
# cluster true = 120157
# cluste true positive = 115130
# cluster positive = 3452776
# purity = 0.033344184505453005
# efficiency = 0.9581630699834384
# 357.7587695121765
# ------ 1.5000000000000004 ------
# -----------
# cluster true = 113355
# cluste true positive = 109135
# cluster positive = 4574113
# purity = 0.023859270638919503
# efficiency = 0.9627718230338318
# -----------
# cluster true = 103420
# cluste true positive = 99707
# cluster positive = 4011835
# purity = 0.02485321554849589
# efficiency = 0.9640978534132663
# -----------
# cluster true = 144774
# cluste true positive = 139322
# cluster positive = 7307973
# purity = 0.01906438351646893
# efficiency = 0.9623413043778579
# -----------
# cluster true = 109839
# cluste true positive = 105650
# cluster positive = 4406962
# purity = 0.023973431130107317
# efficiency = 0.961862362184652
# -----------
# cluster true = 120157
# cluste true positive = 116141
# cluster positive = 5062387
# purity = 0.022941944185618367
# efficiency = 0.9665770616776385
# 346.54269766807556
# ------ 1.6000000000000005 ------
# -----------
# cluster true = 113355
# cluste true positive = 109939
# cluster positive = 6433206
# purity = 0.0170893019747852
# efficiency = 0.9698645847117463
# -----------
# cluster true = 103420
# cluste true positive = 100381
# cluster positive = 5666694
# purity = 0.017714208672640522
# efficiency = 0.9706149680912782
# -----------
# cluster true = 144774
# cluste true positive = 140193
# cluster positive = 10083800
# purity = 0.013902794581407803
# efficiency = 0.9683575780181525
# -----------
# cluster true = 109839
# cluste true positive = 106395
# cluster positive = 6210272
# purity = 0.01713209985005488
# efficiency = 0.9686450167973124
# -----------
# cluster true = 120157
# cluste true positive = 116906
# cluster positive = 7119378
# purity = 0.016420816537624495
# efficiency = 0.9729437319506978
# 342.3083941936493
# ------ 1.7000000000000006 ------
# -----------
# cluster true = 113355
# cluste true positive = 110453
# cluster positive = 8611831
# purity = 0.012825727769158498
# efficiency = 0.9743990119535971
# -----------
# cluster true = 103420
# cluste true positive = 100826
# cluster positive = 7617993
# purity = 0.013235244506000466
# efficiency = 0.974917810868304
# -----------
# cluster true = 144774
# cluste true positive = 140774
# cluster positive = 13227211
# purity = 0.010642757569982063
# efficiency = 0.9723707295508862
# -----------
# cluster true = 109839
# cluste true positive = 106891
# cluster positive = 8323484
# purity = 0.012842098332861577
# efficiency = 0.9731607170494997
# -----------
# cluster true = 120157
# cluste true positive = 117345
# cluster positive = 9538867
# purity = 0.012301775462431754
# efficiency = 0.9765972852185058
# 345.3391435146332
# ------ 1.8000000000000007 ------
# -----------
# cluster true = 113355
# cluste true positive = 110735
# cluster positive = 11042663
# purity = 0.010027925329243499
# efficiency = 0.976886771646597
# -----------
# cluster true = 103420
# cluste true positive = 101132
# cluster positive = 9793445
# purity = 0.010326499000096493
# efficiency = 0.9778766196093599
# -----------
# cluster true = 144774
# cluste true positive = 141125
# cluster positive = 16627955
# purity = 0.008487213250216277
# efficiency = 0.9747951980327959
# -----------
# cluster true = 109839
# cluste true positive = 107226
# cluster positive = 10697785
# purity = 0.010023196390654701
# efficiency = 0.976210635566602
# -----------
# cluster true = 120157
# cluste true positive = 117672
# cluster positive = 12239443
# purity = 0.009614162997450128
# efficiency = 0.9793187246685586
# 363.71906089782715
# ------ 1.9000000000000008 ------
# -----------
# cluster true = 113355
# cluste true positive = 110930
# cluster positive = 13645018
# purity = 0.008129707120943337
# efficiency = 0.9786070310087778
# -----------
# cluster true = 103420
# cluste true positive = 101344
# cluster positive = 12116334
# purity = 0.008364246149041452
# efficiency = 0.9799265132469541
# -----------
# cluster true = 144774
# cluste true positive = 141353
# cluster positive = 20081057
# purity = 0.007039121496443141
# efficiency = 0.9763700664483954
# -----------
# cluster true = 109839
# cluste true positive = 107427
# cluster positive = 13246489
# purity = 0.008109847069665025
# efficiency = 0.9780405866768634
# -----------
# cluster true = 120157
# cluste true positive = 117887
# cluster positive = 15114827
# purity = 0.00779942767456088
# efficiency = 0.9811080503008563
# 358.3796486854553
# CPU times: user 13h 9min 19s, sys: 5min 39s, total: 13h 14min 59s
# Wall time: 1h 5min 11s

# %%
fig3, (ax1,ax2) = plt.subplots(1,2, figsize=(15,7))
fig3.tight_layout(w_pad = 10)
# fig3.suptitle(f'Eventid {evtid}')
ax1.plot(rvals, p_val, label = 'True Positive / Positive')
ax1.plot(rvals, ogp_val, label = "original")
ax1.set_xlabel('r_val')
ax1.set_ylabel('Purity')
# ax1.set_xticks(rvals)
ax1.legend()

ax2.plot(rvals, e_val, label = 'True Positive / True')
ax2.plot(rvals, oge_val, label = "original")
ax2.set_xlabel('r_val')
ax2.set_ylabel('Efficiency')
# ax2.set_xticks(x)
ax2.legend()

# %%
fig4, ax = plt.subplots(figsize=(10,10))
# fig4.suptitle(f'Eventid {evtid}, 100% noise, 1<rval<2, knn=500')
n = len(p_val)-1
colors = cm.inferno_r(np.linspace(0,n))
for i,val in enumerate(rvals):
    ax.scatter(p_val[i],e_val[i], color = colors[i], label = f'{val:.1f}')
ax.set_xlabel('Purity')
ax.set_ylabel('Efficiency')
ax.legend()

# %%
step = np.arange(400,500,10)
ogp_kval = []
oge_kval = []
data_path = "/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/layerless_check/n0/feature_store/"
for n in step:
    print(f"------ {n} ------")
    start = time.time()
    okpv,okev = get_lvl_emb(data_path,emb_model,knn_val=n.item())
    end = time.time()
    print(end-start)
    ogp_kval.append(okpv)
    oge_kval.append(okev)
# Out:
# ------ 400 ------
# -----------
# cluster true = 98107
# cluste true positive = 95650
# cluster positive = 6307657
# purity = 0.015164109272270195
# efficiency = 0.9749559154800371
# -----------
# cluster true = 104909
# cluste true positive = 102088
# cluster positive = 7433363
# purity = 0.013733756847338142
# efficiency = 0.9731100286915326
# -----------
# cluster true = 116478
# cluste true positive = 113539
# cluster positive = 8633383
# purity = 0.013151159863983793
# efficiency = 0.9747677673036969
# -----------
# cluster true = 118662
# cluste true positive = 115602
# cluster positive = 8694227
# purity = 0.01329640921498829
# efficiency = 0.974212469029681
# -----------
# cluster true = 103195
# cluste true positive = 100565
# cluster positive = 6848167
# purity = 0.01468495146219419
# efficiency = 0.9745142691021852
# 284.2451341152191
# ------ 410 ------
# -----------
# cluster true = 98107
# cluste true positive = 95661
# cluster positive = 6346134
# purity = 0.01507390168565618
# efficiency = 0.9750680379585555
# -----------
# cluster true = 104909
# cluste true positive = 102102
# cluster positive = 7482266
# purity = 0.01364586610526811
# efficiency = 0.9732434776806566
# -----------
# cluster true = 116478
# cluste true positive = 113557
# cluster positive = 8694840
# purity = 0.01306027482966909
# efficiency = 0.9749223029241574
# -----------
# cluster true = 118662
# cluste true positive = 115625
# cluster positive = 8750918
# purity = 0.013212899492373257
# efficiency = 0.9744062968768434
# -----------
# cluster true = 103195
# cluste true positive = 100577
# cluster positive = 6888581
# purity = 0.01460053964669937
# efficiency = 0.9746305538059015
# 289.2756087779999
# ------ 420 ------
# -----------
# cluster true = 98107
# cluste true positive = 95675
# cluster positive = 6382633
# purity = 0.014989895236025634
# efficiency = 0.9752107392948516
# -----------
# cluster true = 104909
# cluste true positive = 102114
# cluster positive = 7529348
# purity = 0.013562130479292497
# efficiency = 0.9733578625284771
# -----------
# cluster true = 116478
# cluste true positive = 113574
# cluster positive = 8753997
# purity = 0.012973959209718715
# efficiency = 0.97506825323237
# -----------
# cluster true = 118662
# cluste true positive = 115647
# cluster positive = 8805586
# purity = 0.013133367841731374
# efficiency = 0.9745916974263032
# -----------
# cluster true = 103195
# cluste true positive = 100594
# cluster positive = 6927454
# purity = 0.014521063582666879
# efficiency = 0.9747952904694995
# 294.19055461883545
# ------ 430 ------
# -----------
# cluster true = 98107
# cluste true positive = 95688
# cluster positive = 6417706
# purity = 0.014910000551598968
# efficiency = 0.9753432476785551
# -----------
# cluster true = 104909
# cluste true positive = 102129
# cluster positive = 7574649
# purity = 0.013483000994501528
# efficiency = 0.9735008435882527
# -----------
# cluster true = 116478
# cluste true positive = 113583
# cluster positive = 8811246
# purity = 0.012890685380932503
# efficiency = 0.9751455210426003
# -----------
# cluster true = 118662
# cluste true positive = 115667
# cluster positive = 8858344
# purity = 0.01305740666652819
# efficiency = 0.9747602433803576
# -----------
# cluster true = 103195
# cluste true positive = 100606
# cluster positive = 6964865
# purity = 0.014444788233512064
# efficiency = 0.9749115751732158
# 291.338894367218
# ------ 440 ------
# -----------
# cluster true = 98107
# cluste true positive = 95694
# cluster positive = 6451467
# purity = 0.014832905446156664
# efficiency = 0.9754044053941106
# -----------
# cluster true = 104909
# cluste true positive = 102145
# cluster positive = 7618481
# purity = 0.013407528351124062
# efficiency = 0.97365335671868
# -----------
# cluster true = 116478
# cluste true positive = 113597
# cluster positive = 8866517
# purity = 0.012811907990476983
# efficiency = 0.9752657154140696
# -----------
# cluster true = 118662
# cluste true positive = 115696
# cluster positive = 8909010
# purity = 0.012986403652033166
# efficiency = 0.9750046350137365
# -----------
# cluster true = 103195
# cluste true positive = 100618
# cluster positive = 7000650
# purity = 0.014372665395356145
# efficiency = 0.975027859876932
# 288.7491593360901
# ------ 450 ------
# -----------
# cluster true = 98107
# cluste true positive = 95704
# cluster positive = 6483632
# purity = 0.014760862430193446
# efficiency = 0.9755063349200362
# -----------
# cluster true = 104909
# cluste true positive = 102160
# cluster positive = 7660398
# purity = 0.013336121700204089
# efficiency = 0.9737963377784556
# -----------
# cluster true = 116478
# cluste true positive = 113608
# cluster positive = 8919917
# purity = 0.012736441381685502
# efficiency = 0.9753601538487955
# -----------
# cluster true = 118662
# cluste true positive = 115712
# cluster positive = 8958203
# purity = 0.01291687629762353
# efficiency = 0.97513947177698
# -----------
# cluster true = 103195
# cluste true positive = 100630
# cluster positive = 7035131
# purity = 0.01430392696312265
# efficiency = 0.9751441445806482
# 290.22179555892944
# ------ 460 ------
# -----------
# cluster true = 98107
# cluste true positive = 95707
# cluster positive = 6514726
# purity = 0.014690871112614714
# efficiency = 0.975536913777814
# -----------
# cluster true = 104909
# cluste true positive = 102172
# cluster positive = 7701001
# purity = 0.013267366151491215
# efficiency = 0.9739107226262761
# -----------
# cluster true = 116478
# cluste true positive = 113620
# cluster positive = 8971630
# purity = 0.012664365338294157
# efficiency = 0.9754631775957692
# -----------
# cluster true = 118662
# cluste true positive = 115730
# cluster positive = 9005479
# purity = 0.012851065445824704
# efficiency = 0.9752911631356289
# -----------
# cluster true = 103195
# cluste true positive = 100641
# cluster positive = 7068095
# purity = 0.014238772964992688
# efficiency = 0.9752507388923882
# 290.76708602905273
# ------ 470 ------
# -----------
# cluster true = 98107
# cluste true positive = 95713
# cluster positive = 6544413
# purity = 0.014625146670908452
# efficiency = 0.9755980714933695
# -----------
# cluster true = 104909
# cluste true positive = 102183
# cluster positive = 7740073
# purity = 0.013201813471268295
# efficiency = 0.9740155754034449
# -----------
# cluster true = 116478
# cluste true positive = 113632
# cluster positive = 9021558
# purity = 0.01259560710023701
# efficiency = 0.9755662013427429
# -----------
# cluster true = 118662
# cluste true positive = 115746
# cluster positive = 9051128
# purity = 0.012788019349632444
# efficiency = 0.9754259998988725
# -----------
# cluster true = 103195
# cluste true positive = 100649
# cluster positive = 7100018
# purity = 0.014175879554108173
# efficiency = 0.975328262028199
# 295.9649934768677
# ------ 480 ------
# -----------
# cluster true = 98107
# cluste true positive = 95719
# cluster positive = 6573201
# purity = 0.014562007156026418
# efficiency = 0.9756592292089249
# -----------
# cluster true = 104909
# cluste true positive = 102204
# cluster positive = 7777715
# purity = 0.013140620349292819
# efficiency = 0.9742157488871308
# -----------
# cluster true = 116478
# cluste true positive = 113647
# cluster positive = 9069442
# purity = 0.012530759885779081
# efficiency = 0.9756949810264599
# -----------
# cluster true = 118662
# cluste true positive = 115760
# cluster positive = 9094993
# purity = 0.01272788225345528
# efficiency = 0.9755439820667104
# -----------
# cluster true = 103195
# cluste true positive = 100657
# cluster positive = 7130784
# purity = 0.014115839155974995
# efficiency = 0.9754057851640099
# 296.2488920688629
# ------ 490 ------
# -----------
# cluster true = 98107
# cluste true positive = 95724
# cluster positive = 6600478
# purity = 0.014502586024830323
# efficiency = 0.9757101939718879
# -----------
# cluster true = 104909
# cluste true positive = 102218
# cluster positive = 7814298
# purity = 0.013080893510843841
# efficiency = 0.9743491978762546
# -----------
# cluster true = 116478
# cluste true positive = 113656
# cluster positive = 9115600
# purity = 0.012468296107771294
# efficiency = 0.9757722488366902
# -----------
# cluster true = 118662
# cluste true positive = 115772
# cluster positive = 9137168
# purity = 0.012670446685450022
# efficiency = 0.9756451096391431
# -----------
# cluster true = 103195
# cluste true positive = 100663
# cluster positive = 7160254
# purity = 0.01405857948614672
# efficiency = 0.975463927515868
# 296.45662808418274

# %%
# %%time
step = np.arange(400,500,10)
p_kval = []
e_kval = []
data_path = f"/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/misaligned/new_mis/shift_x_v8_pre/1/feature_store/"
for n in step:
    print(f"------ {n} ------")
    start = time.time()
    pv,ev = get_lvl_emb(data_path,emb_model,knn_val=n.item())
    end = time.time()
    print(end-start)
    p_kval.append(pv)
    e_kval.append(ev)
# Out:
# ------ 400 ------
# -----------
# cluster true = 113355
# cluste true positive = 110295
# cluster positive = 8134527
# purity = 0.013558870724751421
# efficiency = 0.9730051607780865
# -----------
# cluster true = 103420
# cluste true positive = 100698
# cluster positive = 7212040
# purity = 0.013962484955712947
# efficiency = 0.9736801392380584
# -----------
# cluster true = 144774
# cluste true positive = 140457
# cluster positive = 12336203
# purity = 0.011385756216884563
# efficiency = 0.9701811098677939
# -----------
# cluster true = 109839
# cluste true positive = 106757
# cluster positive = 7866538
# purity = 0.013571027051544149
# efficiency = 0.9719407496426588
# -----------
# cluster true = 120157
# cluste true positive = 117185
# cluster positive = 9014262
# purity = 0.01299995496026186
# efficiency = 0.9752656940502842
# 348.2992367744446
# ------ 410 ------
# -----------
# cluster true = 113355
# cluste true positive = 110310
# cluster positive = 8189945
# purity = 0.013468954919721682
# efficiency = 0.9731374884213312
# -----------
# cluster true = 103420
# cluste true positive = 100714
# cluster positive = 7260245
# purity = 0.013871983658953658
# efficiency = 0.9738348481918391
# -----------
# cluster true = 144774
# cluste true positive = 140490
# cluster positive = 12438990
# purity = 0.011294325343134771
# efficiency = 0.9704090513489991
# -----------
# cluster true = 109839
# cluste true positive = 106772
# cluster positive = 7919899
# purity = 0.013481485054291727
# efficiency = 0.97207731315835
# -----------
# cluster true = 120157
# cluste true positive = 117200
# cluster positive = 9075188
# purity = 0.012914333014368408
# efficiency = 0.975390530722305
# 354.81009435653687
# ------ 420 ------
# -----------
# cluster true = 113355
# cluste true positive = 110331
# cluster positive = 8243571
# purity = 0.013383884241428867
# efficiency = 0.9733227471218737
# -----------
# cluster true = 103420
# cluste true positive = 100730
# cluster positive = 7306063
# purity = 0.01378717922361195
# efficiency = 0.9739895571456199
# -----------
# cluster true = 144774
# cluste true positive = 140514
# cluster positive = 12538115
# purity = 0.011206947774844944
# efficiency = 0.9705748269716938
# -----------
# cluster true = 109839
# cluste true positive = 106787
# cluster positive = 7971266
# purity = 0.013396491849600803
# efficiency = 0.9722138766740411
# -----------
# cluster true = 120157
# cluste true positive = 117215
# cluster positive = 9134317
# purity = 0.0128323770677107
# efficiency = 0.9755153673943258
# 342.09758496284485
# ------ 430 ------
# -----------
# cluster true = 113355
# cluste true positive = 110346
# cluster positive = 8295386
# purity = 0.013302093477024457
# efficiency = 0.9734550747651184
# -----------
# cluster true = 103420
# cluste true positive = 100750
# cluster positive = 7350406
# purity = 0.013706725859768834
# efficiency = 0.9741829433378457
# -----------
# cluster true = 144774
# cluste true positive = 140546
# cluster positive = 12634043
# purity = 0.01112438828963935
# efficiency = 0.9707958611352867
# -----------
# cluster true = 109839
# cluste true positive = 106806
# cluster positive = 8020648
# purity = 0.01331638042213048
# efficiency = 0.9723868571272499
# -----------
# cluster true = 120157
# cluste true positive = 117237
# cluster positive = 9191406
# purity = 0.012755067070261068
# efficiency = 0.9756984611799562
# 349.0653841495514
# ------ 440 ------
# -----------
# cluster true = 113355
# cluste true positive = 110368
# cluster positive = 8345153
# purity = 0.013225401619359166
# efficiency = 0.9736491553085439
# -----------
# cluster true = 103420
# cluste true positive = 100764
# cluster positive = 7393336
# purity = 0.01362903025102606
# efficiency = 0.9743183136724037
# -----------
# cluster true = 144774
# cluste true positive = 140576
# cluster positive = 12727119
# purity = 0.011045390555395922
# efficiency = 0.971003080663655
# -----------
# cluster true = 109839
# cluste true positive = 106824
# cluster positive = 8068864
# purity = 0.01323903835781592
# efficiency = 0.9725507333460792
# -----------
# cluster true = 120157
# cluste true positive = 117256
# cluster positive = 9246184
# purity = 0.012681555980283326
# efficiency = 0.9758565876311825
# 330.2114329338074
# ------ 450 ------
# -----------
# cluster true = 113355
# cluste true positive = 110387
# cluster positive = 8393340
# purity = 0.013151736972409078
# efficiency = 0.9738167703233206
# -----------
# cluster true = 103420
# cluste true positive = 100774
# cluster positive = 7434378
# purity = 0.013555135345552782
# efficiency = 0.9744150067685168
# -----------
# cluster true = 144774
# cluste true positive = 140607
# cluster positive = 12816770
# purity = 0.01097054874199974
# efficiency = 0.9712172075096357
# -----------
# cluster true = 109839
# cluste true positive = 106835
# cluster positive = 8115088
# purity = 0.013164983546697213
# efficiency = 0.9726508799242528
# -----------
# cluster true = 120157
# cluste true positive = 117273
# cluster positive = 9299192
# purity = 0.012611095673688639
# efficiency = 0.9759980691928061
# 338.1119990348816
# ------ 460 ------
# -----------
# cluster true = 113355
# cluste true positive = 110402
# cluster positive = 8440271
# purity = 0.01308038568903771
# efficiency = 0.9739490979665653
# -----------
# cluster true = 103420
# cluste true positive = 100784
# cluster positive = 7473968
# purity = 0.013484671060941122
# efficiency = 0.9745116998646297
# -----------
# cluster true = 144774
# cluste true positive = 140647
# cluster positive = 12903877
# purity = 0.010899592424819301
# efficiency = 0.9714935002141268
# -----------
# cluster true = 109839
# cluste true positive = 106851
# cluster positive = 8159644
# purity = 0.013095056598057464
# efficiency = 0.9727965476743233
# -----------
# cluster true = 120157
# cluste true positive = 117284
# cluster positive = 9350472
# purity = 0.012543110123210893
# efficiency = 0.9760896160856213
# 360.06079483032227
# ------ 470 ------
# -----------
# cluster true = 113355
# cluste true positive = 110418
# cluster positive = 8485639
# purity = 0.013012337668383018
# efficiency = 0.9740902474526929
# -----------
# cluster true = 103420
# cluste true positive = 100795
# cluster positive = 7511940
# purity = 0.013417971922033456
# efficiency = 0.9746180622703539
# -----------
# cluster true = 144774
# cluste true positive = 140679
# cluster positive = 12988299
# purity = 0.010831210461046516
# efficiency = 0.9717145343777197
# -----------
# cluster true = 109839
# cluste true positive = 106858
# cluster positive = 8202729
# purity = 0.013027127922914435
# efficiency = 0.9728602773149791
# -----------
# cluster true = 120157
# cluste true positive = 117299
# cluster positive = 9400104
# purity = 0.012478478961509361
# efficiency = 0.9762144527576421
# 357.07244777679443
# ------ 480 ------
# -----------
# cluster true = 113355
# cluste true positive = 110425
# cluster positive = 8529103
# purity = 0.01294684798624193
# efficiency = 0.9741520003528737
# -----------
# cluster true = 103420
# cluste true positive = 100809
# cluster positive = 7548603
# purity = 0.013354656484120308
# efficiency = 0.974753432604912
# -----------
# cluster true = 144774
# cluste true positive = 140711
# cluster positive = 13070350
# purity = 0.010765664270658398
# efficiency = 0.9719355685413127
# -----------
# cluster true = 109839
# cluste true positive = 106871
# cluster positive = 8244110
# purity = 0.012963315627763336
# efficiency = 0.9729786323619115
# -----------
# cluster true = 120157
# cluste true positive = 117313
# cluster positive = 9447978
# purity = 0.012416730860296245
# efficiency = 0.9763309669848614
# 362.85695219039917
# ------ 490 ------
# -----------
# cluster true = 113355
# cluste true positive = 110440
# cluster positive = 8571409
# purity = 0.01288469608672273
# efficiency = 0.9742843279961184
# -----------
# cluster true = 103420
# cluste true positive = 100818
# cluster positive = 7583746
# purity = 0.013293957893631986
# efficiency = 0.9748404563914137
# -----------
# cluster true = 144774
# cluste true positive = 140738
# cluster positive = 13150036
# purity = 0.010702480206137838
# efficiency = 0.9721220661168442
# -----------
# cluster true = 109839
# cluste true positive = 106880
# cluster positive = 8284325
# purity = 0.012901473566041892
# efficiency = 0.9730605704713262
# -----------
# cluster true = 120157
# cluste true positive = 117329
# cluster positive = 9494226
# purity = 0.012357932073662455
# efficiency = 0.9764641261016836
# 349.1448895931244
# CPU times: user 12h 28min 12s, sys: 6min 18s, total: 12h 34min 31s
# Wall time: 58min 11s

# %%
fig5, (ax1,ax2) = plt.subplots(1,2, figsize=(15,7))
# fig5.suptitle(f'Eventid {evtid}, 100% noise, rval=1.7, 400,knnval,500')
ax1.plot(step, p_kval, label = 'True Positive / Positive')
ax1.plot(step, ogp_kval, label = 'Original')
ax1.set_xlabel('knn_val')
ax1.set_ylabel('Purity')
ax1.legend()

ax2.plot(step, e_kval, label = 'True Positive / True')
ax2.plot(step, oge_kval, label = 'Original')
ax2.set_xlabel('knn_val')
ax2.set_ylabel('Efficiency')
ax2.legend()

# %%
fig6, ax = plt.subplots(figsize=(10,10))
# fig6.suptitle(f'Eventid {evtid}, 100% noise, 1<rval<2, knn=500')
n = len(p_kval)-1
colors = cm.inferno_r(np.linspace(0,n))
for i,val in enumerate(step):
    ax.scatter(p_kval[i],e_kval[i], color = colors[i], label = f'{val:.1f}')
ax.set_xlabel('Purity')
ax.set_ylabel('Efficiency')
ax.legend()
