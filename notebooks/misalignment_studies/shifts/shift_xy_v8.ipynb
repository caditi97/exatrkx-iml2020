# %% [markdown]
# # Embedding and Filtering Inference

# %% [markdown]
# Set default input and output directories according to local paths for data

# %%
import os
os.environ['TRKXINPUTDIR']="/global/cfs/cdirs/m3443/data/trackml-kaggle/train_10evts"
os.environ['TRKXOUTPUTDIR']= "/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/misaligned/new_mis/shift_xy_v8_pre/"

# %% [markdown]
# Import necessary libraries and functions

# %%
import pkg_resources
import yaml
import pprint
import random
random.seed(1234)
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import tqdm
from os import listdir
from os.path import isfile, join
import matplotlib.cm as cm
import sys
import time
# %matplotlib widget

sys.path.append('/global/homes/c/caditi97/exatrkx-iml2020/exatrkx/src/')

# 3rd party
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from trackml.dataset import load_event
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import ModelCheckpoint


# local import
from exatrkx import config_dict # for accessing predefined configuration files
from exatrkx import outdir_dict # for accessing predefined output directories
from exatrkx.src import utils_dir
from exatrkx.src import utils_robust
from utils_robust import *


# for preprocessing
from exatrkx import FeatureStore
from exatrkx.src import utils_torch

# for embedding
from exatrkx import LayerlessEmbedding
from exatrkx.src import utils_torch
from torch_cluster import radius_graph
from utils_torch import build_edges
from embedding.embedding_base import *

# for filtering
from exatrkx import VanillaFilter

# for GNN
import tensorflow as tf
from graph_nets import utils_tf
from exatrkx import SegmentClassifier
import sonnet as snt

# for labeling
from exatrkx.scripts.tracks_from_gnn import prepare as prepare_labeling
from exatrkx.scripts.tracks_from_gnn import clustering as dbscan_clustering

# track efficiency
from trackml.score import _analyze_tracks
from exatrkx.scripts.eval_reco_trkx import make_cmp_plot, pt_configs, eta_configs
from functools import partial

# %%
noise_keep = ['0','0.2','0.4','0.6','0.8','1']
plt.rcParams.update({'axes.titlesize' : 16, 'axes.labelsize' : 16, 'lines.linewidth' : 2, 'lines.markersize' : 10,
                    'xtick.labelsize' : 14, 'xtick.major.width' : 2,
                    'ytick.labelsize' : 14, 'ytick.major.width' : 2,
                    'grid.alpha' : 0.5, "legend.frameon" : False, 'legend.fontsize' : 16})
noise_labels = [f'{float(n)*0.2*100:.0f}' for n in noise_keep]

# %% [markdown]
# ## Adding Noise

# %%
# noise_keep = ["0", "0.2", "0.4", "0.6", "0.8", "1"]
# plot_noise_dist(noise_keep)
misl = [0.02,0.1,0.4,0.6,0.8,1]

# %% [markdown]
# ## Embedding

# %% [markdown]
# Set checkpoint and other directory paths

# %%
embed_ckpt_dir = '/global/cfs/cdirs/m3443/data/lightning_models/embedding/checkpoints/epoch=10.ckpt'
filter_ckpt_dir = '/global/cfs/cdirs/m3443/data/lightning_models/filtering/checkpoints/epoch=92.ckpt'
gnn_ckpt_dir = '/global/cfs/cdirs/m3443/data/lightning_models/gnn'
plots_dir = '/global/homes/c/caditi97/exatrkx-iml2020/exatrkx/src/plots/run1' # needs to change...

# %% [markdown]
# Fixing some parameters

# %%
ckpt_idx = -1 # which GNN checkpoint to load
dbscan_epsilon, dbscan_minsamples = 0.25, 2 # hyperparameters for DBScan
min_hits = 5 # minimum number of hits associated with a particle to define "reconstructable particles"
frac_reco_matched, frac_truth_matched = 0.5, 0.5 # parameters for track matching

# %% [markdown]
# Load embedding model from checkpoint

# %%
emb_ckpt = torch.load(embed_ckpt_dir, map_location='cpu')
emb_ckpt['hyper_parameters']['train_split'] = [8,1,1]
emb_ckpt['hyper_parameters']['clustering'] = 'build_edges'
emb_ckpt['hyper_parameters']['knn_val'] = 500
emb_ckpt['hyper_parameters']['r_val'] = 1.7
emb_ckpt['hyper_parameters']
# Out:
# "adjacent":       False
# "clustering":     build_edges
# "emb_dim":        8
# "emb_hidden":     512
# "endcaps":        True
# "factor":         0.3
# "in_channels":    12
# "input_dir":      /global/cscratch1/sd/danieltm/ExaTrkX/trackml/feature_store_endcaps
# "knn":            20
# "knn_val":        500
# "layerless":      True
# "layerwise":      False
# "lr":             0.002
# "margin":         1
# "max_epochs":     100
# "nb_layer":       6
# "noise":          False
# "output_dir":     global/cscratch1/sd/danieltm/ExaTrkX/trackml_processed/embedding_processed/0_pt_cut_endcaps
# "overwrite":      True
# "patience":       5
# "project":        EmbeddingStudy
# "pt_min":         0
# "r_train":        1
# "r_val":          1.7
# "randomisation":  2
# "regime":         ['rp', 'hnm', 'ci']
# "train_split":    [8, 1, 1]
# "wandb_save_dir": /global/cscratch1/sd/danieltm/ExaTrkX/wandb_data
# "warmup":         500
# "weight":         4

# %%
emb_model = LayerlessEmbedding(emb_ckpt['hyper_parameters'])
emb_model.load_state_dict(emb_ckpt["state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# Put model in evaluation state

# %%
emb_model.eval()
# Out:
# LayerlessEmbedding(
#   (layers): ModuleList(
#     (0): Linear(in_features=12, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=512, bias=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#   )
#   (emb_layer): Linear(in_features=512, out_features=8, bias=True)
#   (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   (act): Tanh()
# )

# %% [markdown]
# Define embedding metrics (function gets metrics for one event)

# %%
def get_emb_metrics(data_path, emb_model,r_val=1.7,knn_val=500):
    data = torch.load(data_path)
    spatial = emb_model(torch.cat([data.cell_data, data.x], axis=-1))
    
    if(torch.cuda.is_available()):
        spatial = spatial.cuda()
        
    e_spatial = utils_torch.build_edges(spatial, r_val, knn_val)
    e_spatial_np = e_spatial.cpu().numpy()
    
    # remove R dist from out to in
    R_dist = torch.sqrt(data.x[:,0]**2 + data.x[:,2]**2)
    
    e_spatial_np = e_spatial_np[:, (R_dist[e_spatial_np[0]] <= R_dist[e_spatial_np[1]])]
    e_bidir = torch.cat([data.layerless_true_edges,torch.stack([data.layerless_true_edges[1],
                        data.layerless_true_edges[0]], axis=1).T], axis=-1)
    e_spatial_n, y_cluster = graph_intersection(torch.from_numpy(e_spatial_np), e_bidir)
    
    cluster_true = len(data.layerless_true_edges[0])
    cluster_true_positive = y_cluster.sum()
    cluster_positive = len(e_spatial_n[0])
    purity = cluster_true_positive/cluster_positive
    eff = cluster_true_positive/cluster_true
    
    print("-----------")
    print(f"cluster true = {cluster_true}")
    print(f"cluste true positive = {cluster_true_positive}")
    print(f"cluster positive = {cluster_positive}")
    print(f"purity = {purity}")
    print(f"efficiency = {eff}")
    
    return purity, eff

# %%
def get_lvl_emb(mypath,emb_model,r_val=1.7,knn_val=500):
    events = [f for f in listdir(mypath) if isfile(join(mypath, f))][:5]
    p_lvl = []
    e_lvl = []
    for evt in events:
        data_path = join(mypath,evt)
        p, e = get_emb_metrics(data_path, emb_model,r_val,knn_val) 
        p_lvl.append(p)
        e_lvl.append(e)
    
    return np.mean(p_lvl), np.mean(e_lvl)

# %% [markdown]
# Metrics for one event and all noise configurations

# %%
# %%time
p_all = []
e_all = []
misl = [0.02,0.1,0.4,0.6,0.8,1]
for i in misl:
    mypath = f"/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/misaligned/new_mis/shift_xy_v8_pre/{i}/feature_store/"
    print(f"------ {i} ------")
    start = time.time()
    p,e = get_lvl_emb(mypath,emb_model)
    end = time.time()
    print(end-start)
    p_all.append(p)
    e_all.append(e)
# Out:
# ------ 0.02 ------
# -----------
# cluster true = 113355
# cluste true positive = 110453
# cluster positive = 8607524
# purity = 0.012832145457857567
# efficiency = 0.9743990119535971
# -----------
# cluster true = 103420
# cluste true positive = 100830
# cluster positive = 7614678
# purity = 0.013241531683939885
# efficiency = 0.9749564881067492
# -----------
# cluster true = 144774
# cluste true positive = 140785
# cluster positive = 13223404
# purity = 0.0106466534638131
# efficiency = 0.9724467100446212
# -----------
# cluster true = 109839
# cluste true positive = 106889
# cluster positive = 8318837
# purity = 0.012849031661517109
# efficiency = 0.9731425085807409
# -----------
# cluster true = 120157
# cluste true positive = 117349
# cluster positive = 9536571
# purity = 0.012305156643829317
# efficiency = 0.9766305749977113
# 516.4008002281189
# ------ 0.1 ------
# -----------
# cluster true = 113355
# cluste true positive = 110455
# cluster positive = 8607745
# purity = 0.012832048347157125
# efficiency = 0.9744166556393631
# -----------
# cluster true = 103420
# cluste true positive = 100830
# cluster positive = 7614736
# purity = 0.013241430825704266
# efficiency = 0.9749564881067492
# -----------
# cluster true = 144774
# cluste true positive = 140782
# cluster positive = 13222712
# purity = 0.01064698376550892
# efficiency = 0.9724259880917845
# -----------
# cluster true = 109839
# cluste true positive = 106888
# cluster positive = 8318402
# purity = 0.012849583369498131
# efficiency = 0.9731334043463615
# -----------
# cluster true = 120157
# cluste true positive = 117348
# cluster positive = 9536322
# purity = 0.01230537307779666
# efficiency = 0.9766222525529099
# 519.1539607048035
# ------ 0.4 ------
# -----------
# cluster true = 113355
# cluste true positive = 110461
# cluster positive = 8607412
# purity = 0.01283324186178145
# efficiency = 0.974469586696661
# -----------
# cluster true = 103420
# cluste true positive = 100829
# cluster positive = 7615669
# purity = 0.013239677302151656
# efficiency = 0.9749468187971378
# -----------
# cluster true = 144774
# cluste true positive = 140786
# cluster positive = 13221602
# purity = 0.010648180152450512
# efficiency = 0.9724536173622336
# -----------
# cluster true = 109839
# cluste true positive = 106891
# cluster positive = 8318817
# purity = 0.012849302971804765
# efficiency = 0.9731607170494997
# -----------
# cluster true = 120157
# cluste true positive = 117343
# cluster positive = 9535444
# purity = 0.012305981766554341
# efficiency = 0.976580640328903
# 517.4545788764954
# ------ 0.6 ------
# -----------
# cluster true = 113355
# cluste true positive = 110458
# cluster positive = 8607664
# purity = 0.012832517626152694
# efficiency = 0.974443121168012
# -----------
# cluster true = 103420
# cluste true positive = 100825
# cluster positive = 7616525
# purity = 0.01323766415786727
# efficiency = 0.9749081415586928
# -----------
# cluster true = 144774
# cluste true positive = 140786
# cluster positive = 13222601
# purity = 0.010647375656272166
# efficiency = 0.9724536173622336
# -----------
# cluster true = 109839
# cluste true positive = 106890
# cluster positive = 8319278
# purity = 0.012848470744696836
# efficiency = 0.9731516128151203
# -----------
# cluster true = 120157
# cluste true positive = 117345
# cluster positive = 9535316
# purity = 0.012306356705954999
# efficiency = 0.9765972852185058
# 522.3369715213776
# ------ 0.8 ------
# -----------
# cluster true = 113355
# cluste true positive = 110459
# cluster positive = 8608533
# purity = 0.01283133839412592
# efficiency = 0.974451943010895
# -----------
# cluster true = 103420
# cluste true positive = 100824
# cluster positive = 7617717
# purity = 0.013235461490627704
# efficiency = 0.9748984722490814
# -----------
# cluster true = 144774
# cluste true positive = 140785
# cluster positive = 13222113
# purity = 0.010647692997329549
# efficiency = 0.9724467100446212
# -----------
# cluster true = 109839
# cluste true positive = 106889
# cluster positive = 8320121
# purity = 0.012847048738834447
# efficiency = 0.9731425085807409
# -----------
# cluster true = 120157
# cluste true positive = 117344
# cluster positive = 9536167
# purity = 0.012305153632481478
# efficiency = 0.9765889627737044
# 519.1227028369904
# ------ 1 ------
# -----------
# cluster true = 113355
# cluste true positive = 110450
# cluster positive = 8609837
# purity = 0.012828349712079334
# efficiency = 0.9743725464249482
# -----------
# cluster true = 103420
# cluste true positive = 100820
# cluster positive = 7619376
# purity = 0.013232054698442497
# efficiency = 0.9748597950106362
# -----------
# cluster true = 144774
# cluste true positive = 140777
# cluster positive = 13222595
# purity = 0.010646699834639116
# efficiency = 0.9723914515037231
# -----------
# cluster true = 109839
# cluste true positive = 106888
# cluster positive = 8321542
# purity = 0.012844734785932703
# efficiency = 0.9731334043463615
# -----------
# cluster true = 120157
# cluste true positive = 117342
# cluster positive = 9538057
# purity = 0.01230250563610597
# efficiency = 0.9765723178841016
# 519.6660742759705
# CPU times: user 8h 59min 32s, sys: 3min 30s, total: 9h 3min 2s
# Wall time: 51min 54s

# %%
pf = [ round(elem, 3) for elem in p_all ]
ef = [ round(elem, 3) for elem in e_all ]
e_all
# Out:
# [0.974315058736684,
#  0.9743109577474337,
#  0.9743222760468871,
#  0.9743107556245129,
#  0.9743057193318085,
#  0.974265903033954]

# %%
import matplotlib.ticker as ticker
x = np.arange(len(misl))
fig, (axn,axnn) = plt.subplots(1,2, figsize=(15,7))

# fig1.suptitle('Evt 1000')
fig.tight_layout(w_pad = 10)
axn.plot(misl, pf, label = 'True Positive / Positive')
axn.set_xlabel('Misalignment')
axn.set_ylabel('Purity')
axn.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0e'))
axn.set_xticks(misl)
axn.legend()

axnn.plot(misl, ef, label = 'True Positive / True')
axnn.set_xlabel('Misalignment')
axnn.set_ylabel('Efficiency')
axnn.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0e'))
axnn.set_xticks(misl)
axnn.legend()

# %%
fig2, ax = plt.subplots(figsize=(10,10))
# fig2.suptitle(f'Eventid 1000, All noise, rval=1.7, knn=500')
colors = cm.inferno_r(np.linspace(0,5))
for i,mis in enumerate(misl):
    ax.scatter(p_all[i],e_all[i], color = colors[i], label = mis)
ax.set_xlabel('Purity')
ax.set_ylabel('Efficiency')
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0e'))
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0e'))
ax.legend()

# %% [markdown]
# Average metrics for all events and all noise configurations

# %%
# p_avg = []
# e_avg = []
# for i in noise_keep:
#     data_path = f'/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/out{i}/feature_store/'
#     p, e = get_lvl_emb(data_path,emb_model)
#     p_avg.append(p)
#     e_avg.append(e)

# %%
# x = np.arange(len(noise_keep))
# fig2, (ax1,ax2) = plt.subplots(1,2, figsize=(15,7))
# fig2.tight_layout(w_pad = 10)
# fig2.suptitle('10 Events')
# ax1.plot(x, p_avg, label = 'True Positive / Positive')
# ax1.set_xlabel('noise_level')
# ax1.set_ylabel('Purity')
# ax1.set_xticks(x)
# ax1.set_xticklabels(noise_keep)
# ax1.legend()

# ax2.plot(x, e_avg, label = 'True Positive / True')
# ax2.set_xlabel('noise_level')
# ax2.set_ylabel('Efficiency')
# ax2.set_xticks(x)
# ax2.set_xticklabels(noise_keep)
# ax2.legend()

# %% [markdown]
# Tuning Hyperparameters `r_val = 1.7` and `knn_val = 500` with a set level of noise for a specific event.
#
# * `r_val` defines the radius of the clustering method
# * `knn_val` defines the number of maximum neighbors in the embedding space

# %%
# noise_lvl = 1
# evtid = 1000
# set_event = f'/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/outtest/out{noise_lvl}/feature_store/{evtid}'

# %%
rvals = np.arange(1,2,0.1)
ogp_val = []
oge_val = []
for n in rvals:
    data_path = "/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/layerless_check/n0/feature_store/"
    print(f"------ {n} ------")
    start = time.time()
    opv,oev = get_lvl_emb(data_path,emb_model,r_val=n)
    end = time.time()
    print(end-start)
    ogp_val.append(opv)
    oge_val.append(oev)
# Out:
# ------ 1.0 ------
# -----------
# cluster true = 98107
# cluste true positive = 85829
# cluster positive = 486295
# purity = 0.17649574846543764
# efficiency = 0.8748509280683335
# -----------
# cluster true = 104909
# cluste true positive = 91255
# cluster positive = 558842
# purity = 0.16329302378847688
# efficiency = 0.8698491073215835
# -----------
# cluster true = 116478
# cluste true positive = 101816
# cluster positive = 660364
# purity = 0.15418163315989364
# efficiency = 0.8741221518226618
# -----------
# cluster true = 118662
# cluste true positive = 103575
# cluster positive = 658044
# purity = 0.15739828947608367
# efficiency = 0.8728573595590838
# -----------
# cluster true = 103195
# cluste true positive = 90518
# cluster positive = 528838
# purity = 0.17116394812778205
# efficiency = 0.877154900915742
# 385.9146502017975
# ------ 1.1 ------
# -----------
# cluster true = 98107
# cluste true positive = 88958
# cluster positive = 709387
# purity = 0.1254012266929053
# efficiency = 0.9067446767305085
# -----------
# cluster true = 104909
# cluste true positive = 94608
# cluster positive = 826609
# purity = 0.1144531453202179
# efficiency = 0.9018101402167593
# -----------
# cluster true = 116478
# cluste true positive = 105450
# cluster positive = 980460
# purity = 0.10755155743222569
# efficiency = 0.9053211765311905
# -----------
# cluster true = 118662
# cluste true positive = 107374
# cluster positive = 970929
# purity = 0.11058893080750498
# efficiency = 0.9048726635317119
# -----------
# cluster true = 103195
# cluste true positive = 93610
# cluster positive = 771764
# purity = 0.12129355606117932
# efficiency = 0.9071175929066331
# 377.07605481147766
# ------ 1.2000000000000002 ------
# -----------
# cluster true = 98107
# cluste true positive = 91124
# cluster positive = 1052597
# purity = 0.08657064384565033
# efficiency = 0.9288226120460313
# -----------
# cluster true = 104909
# cluste true positive = 96960
# cluster positive = 1240853
# purity = 0.07813979576952307
# efficiency = 0.9242295703895758
# -----------
# cluster true = 116478
# cluste true positive = 108035
# cluster positive = 1476463
# purity = 0.07317149159850264
# efficiency = 0.9275142086917701
# -----------
# cluster true = 118662
# cluste true positive = 110068
# cluster positive = 1459441
# purity = 0.07541791685994843
# efficiency = 0.927575803542836
# -----------
# cluster true = 103195
# cluste true positive = 95734
# cluster positive = 1145883
# purity = 0.08354605138569994
# efficiency = 0.927699985464412
# 376.86270356178284
# ------ 1.3000000000000003 ------
# -----------
# cluster true = 98107
# cluste true positive = 92667
# cluster positive = 1576424
# purity = 0.058783043140677886
# efficiency = 0.9445503378963784
# -----------
# cluster true = 104909
# cluste true positive = 98684
# cluster positive = 1873596
# purity = 0.052670906641559864
# efficiency = 0.9406628601931197
# -----------
# cluster true = 116478
# cluste true positive = 109923
# cluster positive = 2234023
# purity = 0.0492040592240993
# efficiency = 0.9437232782156287
# -----------
# cluster true = 118662
# cluste true positive = 111938
# cluster positive = 2204416
# purity = 0.050778981825571945
# efficiency = 0.9433348502469199
# -----------
# cluster true = 103195
# cluste true positive = 97329
# cluster positive = 1713562
# purity = 0.056799228741066854
# efficiency = 0.9431561606666989
# 346.9314110279083
# ------ 1.4000000000000004 ------
# -----------
# cluster true = 98107
# cluste true positive = 93778
# cluster positive = 2352681
# purity = 0.03986005752586092
# efficiency = 0.955874708226732
# -----------
# cluster true = 104909
# cluste true positive = 99931
# cluster positive = 2813063
# purity = 0.035523911124635314
# efficiency = 0.9525493522957992
# -----------
# cluster true = 116478
# cluste true positive = 111322
# cluster positive = 3355748
# purity = 0.033173527928795604
# efficiency = 0.9557341300503099
# -----------
# cluster true = 118662
# cluste true positive = 113359
# cluster positive = 3307042
# purity = 0.034278064808369535
# efficiency = 0.955310040282483
# -----------
# cluster true = 103195
# cluste true positive = 98526
# cluster positive = 2556862
# purity = 0.03853395294701083
# efficiency = 0.9547555598623965
# 335.13614439964294
# ------ 1.5000000000000004 ------
# -----------
# cluster true = 98107
# cluste true positive = 94664
# cluster positive = 3455551
# purity = 0.027394762803385046
# efficiency = 0.9649056642237557
# -----------
# cluster true = 104909
# cluste true positive = 100918
# cluster positive = 4136759
# purity = 0.024395426467918483
# efficiency = 0.9619575060290347
# -----------
# cluster true = 116478
# cluste true positive = 112335
# cluster positive = 4910033
# purity = 0.02287866497027617
# efficiency = 0.9644310513573379
# -----------
# cluster true = 118662
# cluste true positive = 114431
# cluster positive = 4852067
# purity = 0.02358396947115528
# efficiency = 0.9643441034197974
# -----------
# cluster true = 103195
# cluste true positive = 99514
# cluster positive = 3753320
# purity = 0.026513593298732856
# efficiency = 0.9643296671350357
# 336.9896101951599
# ------ 1.6000000000000005 ------
# -----------
# cluster true = 98107
# cluste true positive = 95302
# cluster positive = 4898695
# purity = 0.019454569022974485
# efficiency = 0.9714087679778202
# -----------
# cluster true = 104909
# cluste true positive = 101729
# cluster positive = 5838306
# purity = 0.017424403585560605
# efficiency = 0.9696880153275697
# -----------
# cluster true = 116478
# cluste true positive = 113123
# cluster positive = 6872137
# purity = 0.01646110955005699
# efficiency = 0.9711962774086094
# -----------
# cluster true = 118662
# cluste true positive = 115228
# cluster positive = 6831738
# purity = 0.016866571873804293
# efficiency = 0.9710606596888641
# -----------
# cluster true = 103195
# cluste true positive = 100181
# cluster positive = 5316624
# purity = 0.01884297253294572
# efficiency = 0.9707931585832646
# 339.95972418785095
# ------ 1.7000000000000006 ------
# -----------
# cluster true = 98107
# cluste true positive = 95730
# cluster positive = 6626809
# purity = 0.014445866781432812
# efficiency = 0.9757713516874433
# -----------
# cluster true = 104909
# cluste true positive = 102231
# cluster positive = 7849250
# purity = 0.01302430168487435
# efficiency = 0.9744731147947269
# -----------
# cluster true = 116478
# cluste true positive = 113666
# cluster positive = 9160203
# purity = 0.012408676969276772
# efficiency = 0.9758581019591682
# -----------
# cluster true = 118662
# cluste true positive = 115783
# cluster positive = 9178018
# purity = 0.01261525091800866
# efficiency = 0.975737809913873
# -----------
# cluster true = 103195
# cluste true positive = 100664
# cluster positive = 7188799
# purity = 0.014002895337593944
# efficiency = 0.9754736179078444
# 341.34205865859985
# ------ 1.8000000000000007 ------
# -----------
# cluster true = 98107
# cluste true positive = 96008
# cluster positive = 8586004
# purity = 0.011181918853054343
# efficiency = 0.9786049925081799
# -----------
# cluster true = 104909
# cluste true positive = 102567
# cluster positive = 10105387
# purity = 0.010149734987883196
# efficiency = 0.9776758905337006
# -----------
# cluster true = 116478
# cluste true positive = 113957
# cluster positive = 11699167
# purity = 0.009740608027904893
# efficiency = 0.9783564278232799
# -----------
# cluster true = 118662
# cluste true positive = 116121
# cluster positive = 11817231
# purity = 0.009826413649695094
# efficiency = 0.978586236537392
# -----------
# cluster true = 103195
# cluste true positive = 101009
# cluster positive = 9324862
# purity = 0.01083222464847201
# efficiency = 0.978816803139687
# 342.68759870529175
# ------ 1.9000000000000008 ------
# -----------
# cluster true = 98107
# cluste true positive = 96206
# cluster positive = 10743628
# purity = 0.008954703197095059
# efficiency = 0.9806231971215101
# -----------
# cluster true = 104909
# cluste true positive = 102758
# cluster positive = 12529446
# purity = 0.008201320313763274
# efficiency = 0.9794965160281768
# -----------
# cluster true = 116478
# cluste true positive = 114140
# cluster positive = 14411607
# purity = 0.007920005034830606
# efficiency = 0.9799275399646286
# -----------
# cluster true = 118662
# cluste true positive = 116358
# cluster positive = 14653898
# purity = 0.007940412851242721
# efficiency = 0.9805835060929362
# -----------
# cluster true = 103195
# cluste true positive = 101195
# cluster positive = 11660333
# purity = 0.008678568613778012
# efficiency = 0.9806192160472891
# 344.5299725532532

# %%
oge_val
# Out:
# [0.873766889537481,
#  0.9051732499833607,
#  0.927168436026925,
#  0.943085497443749,
#  0.954844758143544,
#  0.9639935984329921,
#  0.9708293757972255,
#  0.9754627992526113,
#  0.9784080701084479,
#  0.9802499950509083]

# %%
# %%time
rvals = np.arange(1,2,0.1)
p_val = []
e_val = []
for n in rvals:
    data_path = f"/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/misaligned/new_mis/shift_xy_v8_pre/1/feature_store/"
    print(f"------ {n} ------")
    start = time.time()
    pv,ev = get_lvl_emb(data_path,emb_model,r_val=n)
    end = time.time()
    print(end-start)
    p_val.append(pv)
    e_val.append(ev)
# Out:
# ------ 1.0 ------
# -----------
# cluster true = 113355
# cluste true positive = 98361
# cluster positive = 622140
# purity = 0.15810107049860161
# efficiency = 0.867725287812624
# -----------
# cluster true = 103420
# cluste true positive = 89938
# cluster positive = 541780
# purity = 0.16600465133449002
# efficiency = 0.8696383678205376
# -----------
# cluster true = 144774
# cluste true positive = 125795
# cluster positive = 953983
# purity = 0.1318629367609276
# efficiency = 0.8689060190365674
# -----------
# cluster true = 109839
# cluste true positive = 95450
# cluster positive = 594827
# purity = 0.16046682480788532
# efficiency = 0.8689991715146714
# -----------
# cluster true = 120157
# cluste true positive = 105562
# cluster positive = 685714
# purity = 0.15394464747693645
# efficiency = 0.878533918123788
# 401.0403742790222
# ------ 1.1 ------
# -----------
# cluster true = 113355
# cluste true positive = 102013
# cluster positive = 919612
# purity = 0.11093047937608469
# efficiency = 0.8999426580212606
# -----------
# cluster true = 103420
# cluste true positive = 93237
# cluster positive = 801739
# purity = 0.11629345709763401
# efficiency = 0.9015374202281957
# -----------
# cluster true = 144774
# cluste true positive = 130508
# cluster positive = 1436363
# purity = 0.09086004025444822
# efficiency = 0.9014602069432357
# -----------
# cluster true = 109839
# cluste true positive = 98966
# cluster positive = 879493
# purity = 0.11252619406862817
# efficiency = 0.9010096595926765
# -----------
# cluster true = 120157
# cluste true positive = 109248
# cluster positive = 1014304
# purity = 0.10770735400826577
# efficiency = 0.9092104496616926
# 401.4580497741699
# ------ 1.2000000000000002 ------
# -----------
# cluster true = 113355
# cluste true positive = 104663
# cluster positive = 1380214
# purity = 0.07583099432406859
# efficiency = 0.923320541661153
# -----------
# cluster true = 103420
# cluste true positive = 95677
# cluster positive = 1207255
# purity = 0.07925169081925525
# efficiency = 0.9251305356797525
# -----------
# cluster true = 144774
# cluste true positive = 133921
# cluster positive = 2192120
# purity = 0.06109200226264985
# efficiency = 0.925034881953942
# -----------
# cluster true = 109839
# cluste true positive = 101385
# cluster positive = 1323135
# purity = 0.07662483420059178
# efficiency = 0.923032802556469
# -----------
# cluster true = 120157
# cluste true positive = 111769
# cluster positive = 1523638
# purity = 0.07335666345943065
# efficiency = 0.9301913330059839
# 403.88269448280334
# ------ 1.3000000000000003 ------
# -----------
# cluster true = 113355
# cluste true positive = 106537
# cluster positive = 2080918
# purity = 0.05119711588827623
# efficiency = 0.9398526752238543
# -----------
# cluster true = 103420
# cluste true positive = 97472
# cluster positive = 1823081
# purity = 0.05346553444416348
# efficiency = 0.9424869464320248
# -----------
# cluster true = 144774
# cluste true positive = 136293
# cluster positive = 3343088
# purity = 0.04076859478422345
# efficiency = 0.9414190393302665
# -----------
# cluster true = 109839
# cluste true positive = 103188
# cluster positive = 1998794
# purity = 0.051625129953361874
# efficiency = 0.939447737142545
# -----------
# cluster true = 120157
# cluste true positive = 113682
# cluster positive = 2301525
# purity = 0.049394206015576626
# efficiency = 0.9461121699110331
# 401.6280291080475
# ------ 1.4000000000000004 ------
# -----------
# cluster true = 113355
# cluste true positive = 108041
# cluster positive = 3119658
# purity = 0.034632321876308235
# efficiency = 0.9531207269198536
# -----------
# cluster true = 103420
# cluste true positive = 98726
# cluster positive = 2735210
# purity = 0.036094486346569365
# efficiency = 0.9546122606845872
# -----------
# cluster true = 144774
# cluste true positive = 138011
# cluster positive = 5036571
# purity = 0.027401777915967034
# efficiency = 0.9532858109881609
# -----------
# cluster true = 109839
# cluste true positive = 104611
# cluster positive = 2999646
# purity = 0.03487444851825849
# efficiency = 0.9524030626644452
# -----------
# cluster true = 120157
# cluste true positive = 115112
# cluster positive = 3454558
# purity = 0.033321773726190156
# efficiency = 0.9580132659770134
# 357.9042856693268
# ------ 1.5000000000000004 ------
# -----------
# cluster true = 113355
# cluste true positive = 109125
# cluster positive = 4575117
# purity = 0.023851849034680423
# efficiency = 0.962683604605002
# -----------
# cluster true = 103420
# cluste true positive = 99696
# cluster positive = 4015451
# purity = 0.024828095274976585
# efficiency = 0.9639914910075421
# -----------
# cluster true = 144774
# cluste true positive = 139302
# cluster positive = 7309921
# purity = 0.01905656709559515
# efficiency = 0.9622031580256123
# -----------
# cluster true = 109839
# cluste true positive = 105646
# cluster positive = 4409392
# purity = 0.023959312304281406
# efficiency = 0.9618259452471345
# -----------
# cluster true = 120157
# cluste true positive = 116116
# cluster positive = 5065251
# purity = 0.022924036735790587
# efficiency = 0.9663690005576038
# 367.60082721710205
# ------ 1.6000000000000005 ------
# -----------
# cluster true = 113355
# cluste true positive = 109918
# cluster positive = 6433064
# purity = 0.01708641480949047
# efficiency = 0.9696793260112038
# -----------
# cluster true = 103420
# cluste true positive = 100370
# cluster positive = 5670403
# purity = 0.017700681944475553
# efficiency = 0.9705086056855541
# -----------
# cluster true = 144774
# cluste true positive = 140177
# cluster positive = 10083365
# purity = 0.013901807581100158
# efficiency = 0.9682470609363559
# -----------
# cluster true = 109839
# cluste true positive = 106390
# cluster positive = 6211112
# purity = 0.017128977870629284
# efficiency = 0.9685994956254154
# -----------
# cluster true = 120157
# cluste true positive = 116884
# cluster positive = 7119872
# purity = 0.01641658726449015
# efficiency = 0.9727606381650674
# 361.8890588283539
# ------ 1.7000000000000006 ------
# -----------
# cluster true = 113355
# cluste true positive = 110450
# cluster positive = 8609837
# purity = 0.012828349712079334
# efficiency = 0.9743725464249482
# -----------
# cluster true = 103420
# cluste true positive = 100820
# cluster positive = 7619376
# purity = 0.013232054698442497
# efficiency = 0.9748597950106362
# -----------
# cluster true = 144774
# cluste true positive = 140777
# cluster positive = 13222595
# purity = 0.010646699834639116
# efficiency = 0.9723914515037231
# -----------
# cluster true = 109839
# cluste true positive = 106888
# cluster positive = 8321542
# purity = 0.012844734785932703
# efficiency = 0.9731334043463615
# -----------
# cluster true = 120157
# cluste true positive = 117342
# cluster positive = 9538057
# purity = 0.01230250563610597
# efficiency = 0.9765723178841016
# 364.7134356498718
# ------ 1.8000000000000007 ------
# -----------
# cluster true = 113355
# cluste true positive = 110726
# cluster positive = 11037231
# purity = 0.010032045175098718
# efficiency = 0.9768073750606502
# -----------
# cluster true = 103420
# cluste true positive = 101135
# cluster positive = 9792534
# purity = 0.01032776603073321
# efficiency = 0.9779056275381938
# -----------
# cluster true = 144774
# cluste true positive = 141117
# cluster positive = 16617766
# purity = 0.008491935678959494
# efficiency = 0.9747399394918977
# -----------
# cluster true = 109839
# cluste true positive = 107219
# cluster positive = 10692749
# purity = 0.010027262399968427
# efficiency = 0.9761469059259461
# -----------
# cluster true = 120157
# cluste true positive = 117665
# cluster positive = 12234140
# purity = 0.009617758175074015
# efficiency = 0.9792604675549489
# 365.7356369495392
# ------ 1.9000000000000008 ------
# -----------
# cluster true = 113355
# cluste true positive = 110932
# cluster positive = 13633908
# purity = 0.008136478550390687
# efficiency = 0.9786246746945437
# -----------
# cluster true = 103420
# cluste true positive = 101343
# cluster positive = 12111049
# purity = 0.00836781355603466
# efficiency = 0.9799168439373429
# -----------
# cluster true = 144774
# cluste true positive = 141342
# cluster positive = 20066894
# purity = 0.007043541466855807
# efficiency = 0.9762940859546604
# -----------
# cluster true = 109839
# cluste true positive = 107430
# cluster positive = 13236007
# purity = 0.008116496160813454
# efficiency = 0.9780678993800016
# -----------
# cluster true = 120157
# cluste true positive = 117873
# cluster positive = 15105210
# purity = 0.007803466486066728
# efficiency = 0.980991536073637
# 369.43593859672546
# CPU times: user 12h 28min 3s, sys: 5min 44s, total: 12h 33min 47s
# Wall time: 1h 3min 15s

# %%
fig3, (ax1,ax2) = plt.subplots(1,2, figsize=(15,7))
fig3.tight_layout(w_pad = 10)
# fig3.suptitle(f'Eventid {evtid}')
ax1.plot(rvals, p_val, label = 'True Positive / Positive')
ax1.plot(rvals, ogp_val, label = "original")
ax1.set_xlabel('r_val')
ax1.set_ylabel('Purity')
# ax1.set_xticks(rvals)
ax1.legend()

ax2.plot(rvals, e_val, label = 'True Positive / True')
ax2.plot(rvals, oge_val, label = "original")
ax2.set_xlabel('r_val')
ax2.set_ylabel('Efficiency')
# ax2.set_xticks(x)
ax2.legend()

# %%
fig4, ax = plt.subplots(figsize=(10,10))
# fig4.suptitle(f'Eventid {evtid}, 100% noise, 1<rval<2, knn=500')
n = len(p_val)-1
colors = cm.inferno_r(np.linspace(0,n))
for i,val in enumerate(rvals):
    ax.scatter(p_val[i],e_val[i], color = colors[i], label = f'{val:.1f}')
ax.set_xlabel('Purity')
ax.set_ylabel('Efficiency')
ax.legend()

# %%
step = np.arange(400,500,10)
ogp_kval = []
oge_kval = []
data_path = "/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/layerless_check/n0/feature_store/"
for n in step:
    print(f"------ {n} ------")
    start = time.time()
    okpv,okev = get_lvl_emb(data_path,emb_model,knn_val=n.item())
    end = time.time()
    print(end-start)
    ogp_kval.append(okpv)
    oge_kval.append(okev)
# Out:
# ------ 400 ------
# -----------
# cluster true = 98107
# cluste true positive = 95650
# cluster positive = 6307657
# purity = 0.015164109272270195
# efficiency = 0.9749559154800371
# -----------
# cluster true = 104909
# cluste true positive = 102088
# cluster positive = 7433363
# purity = 0.013733756847338142
# efficiency = 0.9731100286915326
# -----------
# cluster true = 116478
# cluste true positive = 113539
# cluster positive = 8633383
# purity = 0.013151159863983793
# efficiency = 0.9747677673036969
# -----------
# cluster true = 118662
# cluste true positive = 115602
# cluster positive = 8694227
# purity = 0.01329640921498829
# efficiency = 0.974212469029681
# -----------
# cluster true = 103195
# cluste true positive = 100565
# cluster positive = 6848167
# purity = 0.01468495146219419
# efficiency = 0.9745142691021852
# 391.4995312690735
# ------ 410 ------
# -----------
# cluster true = 98107
# cluste true positive = 95661
# cluster positive = 6346134
# purity = 0.01507390168565618
# efficiency = 0.9750680379585555
# -----------
# cluster true = 104909
# cluste true positive = 102102
# cluster positive = 7482266
# purity = 0.01364586610526811
# efficiency = 0.9732434776806566
# -----------
# cluster true = 116478
# cluste true positive = 113557
# cluster positive = 8694840
# purity = 0.01306027482966909
# efficiency = 0.9749223029241574
# -----------
# cluster true = 118662
# cluste true positive = 115625
# cluster positive = 8750918
# purity = 0.013212899492373257
# efficiency = 0.9744062968768434
# -----------
# cluster true = 103195
# cluste true positive = 100577
# cluster positive = 6888581
# purity = 0.01460053964669937
# efficiency = 0.9746305538059015
# 430.39437341690063
# ------ 420 ------
# -----------
# cluster true = 98107
# cluste true positive = 95675
# cluster positive = 6382633
# purity = 0.014989895236025634
# efficiency = 0.9752107392948516
# -----------
# cluster true = 104909
# cluste true positive = 102114
# cluster positive = 7529348
# purity = 0.013562130479292497
# efficiency = 0.9733578625284771
# -----------
# cluster true = 116478
# cluste true positive = 113574
# cluster positive = 8753997
# purity = 0.012973959209718715
# efficiency = 0.97506825323237
# -----------
# cluster true = 118662
# cluste true positive = 115647
# cluster positive = 8805586
# purity = 0.013133367841731374
# efficiency = 0.9745916974263032
# -----------
# cluster true = 103195
# cluste true positive = 100594
# cluster positive = 6927454
# purity = 0.014521063582666879
# efficiency = 0.9747952904694995
# 404.36471819877625
# ------ 430 ------
# -----------
# cluster true = 98107
# cluste true positive = 95688
# cluster positive = 6417706
# purity = 0.014910000551598968
# efficiency = 0.9753432476785551
# -----------
# cluster true = 104909
# cluste true positive = 102129
# cluster positive = 7574649
# purity = 0.013483000994501528
# efficiency = 0.9735008435882527
# -----------
# cluster true = 116478
# cluste true positive = 113583
# cluster positive = 8811246
# purity = 0.012890685380932503
# efficiency = 0.9751455210426003
# -----------
# cluster true = 118662
# cluste true positive = 115667
# cluster positive = 8858344
# purity = 0.01305740666652819
# efficiency = 0.9747602433803576
# -----------
# cluster true = 103195
# cluste true positive = 100606
# cluster positive = 6964865
# purity = 0.014444788233512064
# efficiency = 0.9749115751732158
# 394.5106704235077
# ------ 440 ------
# -----------
# cluster true = 98107
# cluste true positive = 95694
# cluster positive = 6451467
# purity = 0.014832905446156664
# efficiency = 0.9754044053941106
# -----------
# cluster true = 104909
# cluste true positive = 102145
# cluster positive = 7618481
# purity = 0.013407528351124062
# efficiency = 0.97365335671868
# -----------
# cluster true = 116478
# cluste true positive = 113597
# cluster positive = 8866517
# purity = 0.012811907990476983
# efficiency = 0.9752657154140696
# -----------
# cluster true = 118662
# cluste true positive = 115696
# cluster positive = 8909010
# purity = 0.012986403652033166
# efficiency = 0.9750046350137365
# -----------
# cluster true = 103195
# cluste true positive = 100618
# cluster positive = 7000650
# purity = 0.014372665395356145
# efficiency = 0.975027859876932
# 432.3719503879547
# ------ 450 ------
# -----------
# cluster true = 98107
# cluste true positive = 95704
# cluster positive = 6483632
# purity = 0.014760862430193446
# efficiency = 0.9755063349200362
# -----------
# cluster true = 104909
# cluste true positive = 102160
# cluster positive = 7660398
# purity = 0.013336121700204089
# efficiency = 0.9737963377784556
# -----------
# cluster true = 116478
# cluste true positive = 113608
# cluster positive = 8919917
# purity = 0.012736441381685502
# efficiency = 0.9753601538487955
# -----------
# cluster true = 118662
# cluste true positive = 115712
# cluster positive = 8958203
# purity = 0.01291687629762353
# efficiency = 0.97513947177698
# -----------
# cluster true = 103195
# cluste true positive = 100630
# cluster positive = 7035131
# purity = 0.01430392696312265
# efficiency = 0.9751441445806482
# 438.79858136177063
# ------ 460 ------
# -----------
# cluster true = 98107
# cluste true positive = 95707
# cluster positive = 6514726
# purity = 0.014690871112614714
# efficiency = 0.975536913777814
# -----------
# cluster true = 104909
# cluste true positive = 102172
# cluster positive = 7701001
# purity = 0.013267366151491215
# efficiency = 0.9739107226262761
# -----------
# cluster true = 116478
# cluste true positive = 113620
# cluster positive = 8971630
# purity = 0.012664365338294157
# efficiency = 0.9754631775957692
# -----------
# cluster true = 118662
# cluste true positive = 115730
# cluster positive = 9005479
# purity = 0.012851065445824704
# efficiency = 0.9752911631356289
# -----------
# cluster true = 103195
# cluste true positive = 100641
# cluster positive = 7068095
# purity = 0.014238772964992688
# efficiency = 0.9752507388923882
# 430.4334318637848
# ------ 470 ------
# -----------
# cluster true = 98107
# cluste true positive = 95713
# cluster positive = 6544413
# purity = 0.014625146670908452
# efficiency = 0.9755980714933695
# -----------
# cluster true = 104909
# cluste true positive = 102183
# cluster positive = 7740073
# purity = 0.013201813471268295
# efficiency = 0.9740155754034449
# -----------
# cluster true = 116478
# cluste true positive = 113632
# cluster positive = 9021558
# purity = 0.01259560710023701
# efficiency = 0.9755662013427429
# -----------
# cluster true = 118662
# cluste true positive = 115746
# cluster positive = 9051128
# purity = 0.012788019349632444
# efficiency = 0.9754259998988725
# -----------
# cluster true = 103195
# cluste true positive = 100649
# cluster positive = 7100018
# purity = 0.014175879554108173
# efficiency = 0.975328262028199
# 435.39546489715576
# ------ 480 ------
# -----------
# cluster true = 98107
# cluste true positive = 95719
# cluster positive = 6573201
# purity = 0.014562007156026418
# efficiency = 0.9756592292089249
# -----------
# cluster true = 104909
# cluste true positive = 102204
# cluster positive = 7777715
# purity = 0.013140620349292819
# efficiency = 0.9742157488871308
# -----------
# cluster true = 116478
# cluste true positive = 113647
# cluster positive = 9069442
# purity = 0.012530759885779081
# efficiency = 0.9756949810264599
# -----------
# cluster true = 118662
# cluste true positive = 115760
# cluster positive = 9094993
# purity = 0.01272788225345528
# efficiency = 0.9755439820667104
# -----------
# cluster true = 103195
# cluste true positive = 100657
# cluster positive = 7130784
# purity = 0.014115839155974995
# efficiency = 0.9754057851640099
# 433.0570583343506
# ------ 490 ------
# -----------
# cluster true = 98107
# cluste true positive = 95724
# cluster positive = 6600478
# purity = 0.014502586024830323
# efficiency = 0.9757101939718879
# -----------
# cluster true = 104909
# cluste true positive = 102218
# cluster positive = 7814298
# purity = 0.013080893510843841
# efficiency = 0.9743491978762546
# -----------
# cluster true = 116478
# cluste true positive = 113656
# cluster positive = 9115600
# purity = 0.012468296107771294
# efficiency = 0.9757722488366902
# -----------
# cluster true = 118662
# cluste true positive = 115772
# cluster positive = 9137168
# purity = 0.012670446685450022
# efficiency = 0.9756451096391431
# -----------
# cluster true = 103195
# cluste true positive = 100663
# cluster positive = 7160254
# purity = 0.01405857948614672
# efficiency = 0.975463927515868
# 365.94108057022095

# %%
# %%time
step = np.arange(400,500,10)
p_kval = []
e_kval = []
data_path = f"/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/misaligned/new_mis/shift_xy_v8_pre/1/feature_store/"
for n in step:
    print(f"------ {n} ------")
    start = time.time()
    pv,ev = get_lvl_emb(data_path,emb_model,knn_val=n.item())
    end = time.time()
    print(end-start)
    p_kval.append(pv)
    e_kval.append(ev)
# Out:
# ------ 400 ------
# -----------
# cluster true = 113355
# cluste true positive = 110294
# cluster positive = 8132869
# purity = 0.013561511933857535
# efficiency = 0.9729963389352035
# -----------
# cluster true = 103420
# cluste true positive = 100690
# cluster positive = 7213290
# purity = 0.013958956315356793
# efficiency = 0.973602784761168
# -----------
# cluster true = 144774
# cluste true positive = 140462
# cluster positive = 12331344
# purity = 0.011390648091562445
# efficiency = 0.9702156464558553
# -----------
# cluster true = 109839
# cluste true positive = 106752
# cluster positive = 7864848
# purity = 0.013573307456164443
# efficiency = 0.9718952284707617
# -----------
# cluster true = 120157
# cluste true positive = 117184
# cluster positive = 9013125
# purity = 0.013001483947021705
# efficiency = 0.9752573716054829
# 446.0280976295471
# ------ 410 ------
# -----------
# cluster true = 113355
# cluste true positive = 110309
# cluster positive = 8188460
# purity = 0.01347127542907946
# efficiency = 0.9731286665784482
# -----------
# cluster true = 103420
# cluste true positive = 100705
# cluster positive = 7261569
# purity = 0.013868214982189112
# efficiency = 0.9737478244053375
# -----------
# cluster true = 144774
# cluste true positive = 140489
# cluster positive = 12433895
# purity = 0.011298872959760398
# efficiency = 0.9704021440313868
# -----------
# cluster true = 109839
# cluste true positive = 106768
# cluster positive = 7918142
# purity = 0.013483971366009853
# efficiency = 0.9720408962208323
# -----------
# cluster true = 120157
# cluste true positive = 117197
# cluster positive = 9074218
# purity = 0.01291538290131447
# efficiency = 0.9753655633879008
# 463.8191411495209
# ------ 420 ------
# -----------
# cluster true = 113355
# cluste true positive = 110330
# cluster positive = 8242053
# purity = 0.013386227921611277
# efficiency = 0.9733139252789907
# -----------
# cluster true = 103420
# cluste true positive = 100720
# cluster positive = 7307541
# purity = 0.013783022223207505
# efficiency = 0.9738928640495068
# -----------
# cluster true = 144774
# cluste true positive = 140521
# cluster positive = 12533141
# purity = 0.011211953970676624
# efficiency = 0.9706231781949798
# -----------
# cluster true = 109839
# cluste true positive = 106783
# cluster positive = 7969395
# purity = 0.0133991350660872
# efficiency = 0.9721774597365235
# -----------
# cluster true = 120157
# cluste true positive = 117212
# cluster positive = 9133302
# purity = 0.012833474684183223
# efficiency = 0.9754904000599216
# 453.1664617061615
# ------ 430 ------
# -----------
# cluster true = 113355
# cluste true positive = 110345
# cluster positive = 8293879
# purity = 0.013304389900069678
# efficiency = 0.9734462529222354
# -----------
# cluster true = 103420
# cluste true positive = 100742
# cluster positive = 7351791
# purity = 0.013703055486751459
# efficiency = 0.9741055888609553
# -----------
# cluster true = 144774
# cluste true positive = 140549
# cluster positive = 12628886
# purity = 0.011129168479310052
# efficiency = 0.9708165830881236
# -----------
# cluster true = 109839
# cluste true positive = 106803
# cluster positive = 8018902
# purity = 0.013318905755426366
# efficiency = 0.9723595444241117
# -----------
# cluster true = 120157
# cluste true positive = 117233
# cluster positive = 9190410
# purity = 0.012756014149531958
# efficiency = 0.9756651714007507
# 458.903546333313
# ------ 440 ------
# -----------
# cluster true = 113355
# cluste true positive = 110369
# cluster positive = 8343607
# purity = 0.013227972026966276
# efficiency = 0.9736579771514269
# -----------
# cluster true = 103420
# cluste true positive = 100754
# cluster positive = 7394722
# purity = 0.013625123432632086
# efficiency = 0.9742216205762908
# -----------
# cluster true = 144774
# cluste true positive = 140579
# cluster positive = 12722097
# purity = 0.011049986492006782
# efficiency = 0.9710238026164919
# -----------
# cluster true = 109839
# cluste true positive = 106819
# cluster positive = 8067075
# purity = 0.013241354518211372
# efficiency = 0.9725052121741822
# -----------
# cluster true = 120157
# cluste true positive = 117254
# cluster positive = 9245165
# purity = 0.01268273740922958
# efficiency = 0.9758399427415798
# 456.303293466568
# ------ 450 ------
# -----------
# cluster true = 113355
# cluste true positive = 110384
# cluster positive = 8391610
# purity = 0.013154090812132594
# efficiency = 0.9737903047946717
# -----------
# cluster true = 103420
# cluste true positive = 100766
# cluster positive = 7435798
# purity = 0.013551470871048407
# efficiency = 0.9743376522916264
# -----------
# cluster true = 144774
# cluste true positive = 140609
# cluster positive = 12811808
# purity = 0.010974953730183905
# efficiency = 0.9712310221448602
# -----------
# cluster true = 109839
# cluste true positive = 106833
# cluster positive = 8113194
# purity = 0.013167810359274041
# efficiency = 0.9726326714554939
# -----------
# cluster true = 120157
# cluste true positive = 117273
# cluster positive = 9298229
# purity = 0.012612401781027334
# efficiency = 0.9759980691928061
# 506.03095865249634
# ------ 460 ------
# -----------
# cluster true = 113355
# cluste true positive = 110401
# cluster positive = 8438596
# purity = 0.0130828635474432
# efficiency = 0.9739402761236823
# -----------
# cluster true = 103420
# cluste true positive = 100775
# cluster positive = 7475276
# purity = 0.013481107587198117
# efficiency = 0.974424676078128
# -----------
# cluster true = 144774
# cluste true positive = 140649
# cluster positive = 12898919
# purity = 0.010903936988828288
# efficiency = 0.9715073148493514
# -----------
# cluster true = 109839
# cluste true positive = 106846
# cluster positive = 8157787
# purity = 0.01309742458340724
# efficiency = 0.9727510265024263
# -----------
# cluster true = 120157
# cluste true positive = 117283
# cluster positive = 9349618
# purity = 0.01254414886255246
# efficiency = 0.97608129364082
# 495.55576944351196
# ------ 470 ------
# -----------
# cluster true = 113355
# cluste true positive = 110417
# cluster positive = 8484052
# purity = 0.013014653847006124
# efficiency = 0.9740814256098099
# -----------
# cluster true = 103420
# cluste true positive = 100786
# cluster positive = 7513235
# purity = 0.013414461280660062
# efficiency = 0.9745310384838523
# -----------
# cluster true = 144774
# cluste true positive = 140684
# cluster positive = 12983538
# purity = 0.010835567316089036
# efficiency = 0.9717490709657811
# -----------
# cluster true = 109839
# cluste true positive = 106856
# cluster positive = 8200829
# purity = 0.013029902220860843
# efficiency = 0.9728420688462204
# -----------
# cluster true = 120157
# cluste true positive = 117300
# cluster positive = 9399353
# purity = 0.012479582371254702
# efficiency = 0.9762227752024435
# 435.00142073631287
# ------ 480 ------
# -----------
# cluster true = 113355
# cluste true positive = 110422
# cluster positive = 8527328
# purity = 0.012949191118249468
# efficiency = 0.9741255348242248
# -----------
# cluster true = 103420
# cluste true positive = 100801
# cluster positive = 7550002
# purity = 0.013351122291093432
# efficiency = 0.9746760781280217
# -----------
# cluster true = 144774
# cluste true positive = 140716
# cluster positive = 13065433
# purity = 0.010770098472817548
# efficiency = 0.9719701051293741
# -----------
# cluster true = 109839
# cluste true positive = 106864
# cluster positive = 8242283
# purity = 0.012965339821503339
# efficiency = 0.9729149027212557
# -----------
# cluster true = 120157
# cluste true positive = 117312
# cluster positive = 9447188
# purity = 0.012417663330082984
# efficiency = 0.9763226445400601
# 403.5825343132019
# ------ 490 ------
# -----------
# cluster true = 113355
# cluste true positive = 110436
# cluster positive = 8569504
# purity = 0.012887093582078964
# efficiency = 0.9742490406245865
# -----------
# cluster true = 103420
# cluste true positive = 100810
# cluster positive = 7585178
# purity = 0.013290393448907856
# efficiency = 0.9747631019145233
# -----------
# cluster true = 144774
# cluste true positive = 140745
# cluster positive = 13145402
# purity = 0.010706785536113692
# efficiency = 0.9721704173401301
# -----------
# cluster true = 109839
# cluste true positive = 106878
# cluster positive = 8282453
# purity = 0.012904148082699655
# efficiency = 0.9730423620025674
# -----------
# cluster true = 120157
# cluste true positive = 117326
# cluster positive = 9493428
# purity = 0.012358654850492362
# efficiency = 0.9764391587672795
# 362.8781132698059
# CPU times: user 13h 52min 4s, sys: 5min 57s, total: 13h 58min 2s
# Wall time: 1h 14min 41s

# %%
fig5, (ax1,ax2) = plt.subplots(1,2, figsize=(15,7))
# fig5.suptitle(f'Eventid {evtid}, 100% noise, rval=1.7, 400,knnval,500')
ax1.plot(step, p_kval, label = 'True Positive / Positive')
ax1.plot(step, ogp_kval, label = 'Original')
ax1.set_xlabel('knn_val')
ax1.set_ylabel('Purity')
ax1.legend()

ax2.plot(step, e_kval, label = 'True Positive / True')
ax2.plot(step, oge_kval, label = 'Original')
ax2.set_xlabel('knn_val')
ax2.set_ylabel('Efficiency')
ax2.legend()

# %%
fig6, ax = plt.subplots(figsize=(10,10))
# fig6.suptitle(f'Eventid {evtid}, 100% noise, 1<rval<2, knn=500')
n = len(p_kval)-1
colors = cm.inferno_r(np.linspace(0,n))
for i,val in enumerate(step):
    ax.scatter(p_kval[i],e_kval[i], color = colors[i], label = f'{val:.1f}')
ax.set_xlabel('Purity')
ax.set_ylabel('Efficiency')
ax.legend()
