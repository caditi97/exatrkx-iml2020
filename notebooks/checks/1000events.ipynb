# %%
import os
os.environ['TRKXINPUTDIR']="/global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all"
os.environ['TRKXOUTPUTDIR']= "/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/outtest"

# %%
import pkg_resources
import yaml
import pprint
import random
import time
import pickle
random.seed(1234)
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import tqdm
from os import listdir
from os.path import isfile, join
import matplotlib.cm as cm
import sys
import warnings
warnings.filterwarnings('ignore')
from os import listdir
from os.path import isfile, join

# %matplotlib widget

sys.path.append('/global/homes/c/caditi97/exatrkx-iml2020/exatrkx/src/')

# 3rd party
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from trackml.dataset import load_event
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import ModelCheckpoint


# local import
from exatrkx import config_dict # for accessing predefined configuration files
from exatrkx import outdir_dict # for accessing predefined output directories
from exatrkx.src import utils_dir
from exatrkx.src import utils_robust
from utils_robust import *


# for preprocessing
from exatrkx import FeatureStore
from exatrkx.src import utils_torch

# for embedding
from exatrkx import LayerlessEmbedding
from exatrkx.src import utils_torch
from torch_cluster import radius_graph
from utils_torch import build_edges
from embedding.embedding_base import *

# for filtering
from exatrkx import VanillaFilter

# for GNN
import tensorflow as tf
from graph_nets import utils_tf
from exatrkx import SegmentClassifier
import sonnet as snt

# for labeling
from exatrkx.scripts.tracks_from_gnn import prepare as prepare_labeling
from exatrkx.scripts.tracks_from_gnn import clustering as dbscan_clustering

# track efficiency
from trackml.score import _analyze_tracks
from exatrkx.scripts.eval_reco_trkx import make_cmp_plot, pt_configs, eta_configs
from functools import partial

# %%
noise_keep = ["0.2", "0.4", "0.6", "0.8", "1"]
embed_ckpt_dir = '/global/cfs/cdirs/m3443/data/lightning_models/embedding/checkpoints/epoch=10.ckpt'
filter_ckpt_dir = '/global/cfs/cdirs/m3443/data/lightning_models/filtering/checkpoints/epoch=92.ckpt'
gnn_ckpt_dir = '/global/cfs/cdirs/m3443/data/lightning_models/gnn'
plots_dir = '/global/homes/c/caditi97/exatrkx-iml2020/exatrkx/src/plots/run1000' # needs to change...
ckpt_idx = -1 # which GNN checkpoint to load
dbscan_epsilon, dbscan_minsamples = 0.25, 2 # hyperparameters for DBScan
min_hits = 5 # minimum number of hits associated with a particle to define "reconstructable particles"
frac_reco_matched, frac_truth_matched = 0.5, 0.5 # parameters for track matching

# %%
emb_ckpt = torch.load(embed_ckpt_dir, map_location='cpu')

emb_ckpt['hyper_parameters']['clustering'] = 'build_edges'
emb_ckpt['hyper_parameters']['knn_val'] = 500
emb_ckpt['hyper_parameters']['r_val'] = 1.7
emb_ckpt['hyper_parameters']
# Out:
# "adjacent":       False
# "clustering":     build_edges
# "emb_dim":        8
# "emb_hidden":     512
# "endcaps":        True
# "factor":         0.3
# "in_channels":    12
# "input_dir":      /global/cscratch1/sd/danieltm/ExaTrkX/trackml/feature_store_endcaps
# "knn":            20
# "knn_val":        500
# "layerless":      True
# "layerwise":      False
# "lr":             0.002
# "margin":         1
# "max_epochs":     100
# "nb_layer":       6
# "noise":          False
# "output_dir":     global/cscratch1/sd/danieltm/ExaTrkX/trackml_processed/embedding_processed/0_pt_cut_endcaps
# "overwrite":      True
# "patience":       5
# "project":        EmbeddingStudy
# "pt_min":         0
# "r_train":        1
# "r_val":          1.7
# "randomisation":  2
# "regime":         ['rp', 'hnm', 'ci']
# "train_split":    [900, 50, 50]
# "wandb_save_dir": /global/cscratch1/sd/danieltm/ExaTrkX/wandb_data
# "warmup":         500
# "weight":         4

# %%
def get_data_np(mypath):
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))][:10]
    data_n = []
    for file in onlyfiles:
        data = torch.load(join(mypath,file))
        data_n.append(data)
    return data_n

# %%
def calc_evts(noise_dir,data_n):
    matched_idx = []
    peta = []
    par_pt = []
    build_times = []
    all_steps = []
    esp_times = []
    f_times = []
    trkeff_times = []
    
    for data in data_n:
        start1 = time.time()
        
        esp_strt = time.time()
        e_spatial = emb_eval(embed_ckpt_dir,data)
        esp_end = time.time()
        
        f_strt = time.time()
        output, f_model = filtering(filter_ckpt_dir,data,e_spatial)
        f_end = time.time()
        
        start = time.time()
        predict_tracks = build_graph(output, f_model,data, e_spatial, gnn_ckpt_dir,ckpt_idx,dbscan_epsilon, dbscan_minsamples)
        end = time.time()
        print("build time---- ")
        print(end - start)
        
        evt_path = data.event_file
        
        trkeff_strt = time.time()
        m_idx, pt, p_pt = track_eff(evt_path, predict_tracks,min_hits,frac_reco_matched, frac_truth_matched)
        trkeff_end = time.time()
        
        end1 = time.time()
        print("all steps time---- ")
        print(end1 - start1)
        
        build_times.append(end - start)
        esp_times.append(esp_end-esp_strt)
        f_times.append(f_end-f_strt)
        trkeff_times.append(trkeff_end-trkeff_strt)
        all_steps.append(end1 - start1)
        
        matched_idx.append(m_idx)
        peta.append(pt)
        par_pt.append(p_pt)
        
    this_dict = {
        'matched_idx' : matched_idx,
        'peta' : peta,
        'par_pt' : par_pt,
        'avg_build_time' : build_times,
        'all_steps' : all_steps,
        'esp_times' : esp_times,
        'f_times' : f_times,
        'trkeff_times' : trkeff_times
    }
    
    return this_dict

# %%
def create_pickle(n):
    noise_dir = f'/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/layerless_check/n{n}/feature_store'
    data_n = get_data_np(noise_dir)
    print(f"------Noise Level {n}------")
    start = time.time()
    dictn = calc_evts(noise_dir,data_n)
    end = time.time()
    print("total time---- ")
    print(end - start)
    dictn['total_time'] = end-start
    
    print("--------------------")

    with open(f'/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/layerless_check/lists_n{n}.pickle', 'wb') as handle:
        pickle.dump(dictn, handle)

# %%
for n in noise_keep:
    create_pickle(n)
# Out:
# ------Noise Level 0.2------
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 18.066550493240356
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7095
# Reconstructed tracks:           10735
# Reconstructable tracks Matched: 6511
# Tracking efficiency:            0.9177
# Tracking purity:               0.6065
# ----------
# all steps time----
# 97.65140390396118
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 10.566899061203003
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7647
# Reconstructed tracks:           12112
# Reconstructable tracks Matched: 6910
# Tracking efficiency:            0.9036
# Tracking purity:               0.5705
# ----------
# all steps time----
# 95.96455883979797
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 11.57659101486206
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8471
# Reconstructed tracks:           13166
# Reconstructable tracks Matched: 7698
# Tracking efficiency:            0.9087
# Tracking purity:               0.5847
# ----------
# all steps time----
# 116.35338950157166
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.095162630081177
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8545
# Reconstructed tracks:           13423
# Reconstructable tracks Matched: 7782
# Tracking efficiency:            0.9107
# Tracking purity:               0.5798
# ----------
# all steps time----
# 115.00104880332947
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 10.000929832458496
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7453
# Reconstructed tracks:           11522
# Reconstructable tracks Matched: 6774
# Tracking efficiency:            0.9089
# Tracking purity:               0.5879
# ----------
# all steps time----
# 90.02449631690979
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 9.957330703735352
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7344
# Reconstructed tracks:           11079
# Reconstructable tracks Matched: 6750
# Tracking efficiency:            0.9191
# Tracking purity:               0.6093
# ----------
# all steps time----
# 89.85865831375122
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 14.10628604888916
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         9685
# Reconstructed tracks:           15178
# Reconstructable tracks Matched: 8737
# Tracking efficiency:            0.9021
# Tracking purity:               0.5756
# ----------
# all steps time----
# 142.08124780654907
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 11.058988809585571
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7837
# Reconstructed tracks:           12304
# Reconstructable tracks Matched: 7112
# Tracking efficiency:            0.9075
# Tracking purity:               0.5780
# ----------
# all steps time----
# 101.15670990943909
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 10.535218238830566
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7829
# Reconstructed tracks:           11829
# Reconstructable tracks Matched: 7161
# Tracking efficiency:            0.9147
# Tracking purity:               0.6054
# ----------
# all steps time----
# 100.18491554260254
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.419821500778198
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8930
# Reconstructed tracks:           14150
# Reconstructable tracks Matched: 8085
# Tracking efficiency:            0.9054
# Tracking purity:               0.5714
# ----------
# all steps time----
# 125.39269256591797
# total time----
# 1076.8104972839355
# --------------------
# ------Noise Level 0.4------
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 9.524648904800415
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7095
# Reconstructed tracks:           10926
# Reconstructable tracks Matched: 6492
# Tracking efficiency:            0.9150
# Tracking purity:               0.5942
# ----------
# all steps time----
# 89.17582368850708
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 11.098332643508911
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7647
# Reconstructed tracks:           12304
# Reconstructable tracks Matched: 6875
# Tracking efficiency:            0.8990
# Tracking purity:               0.5588
# ----------
# all steps time----
# 104.13737463951111
# build time----
# 12.95941162109375
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8545
# Reconstructed tracks:           13776
# Reconstructable tracks Matched: 7759
# Tracking efficiency:            0.9080
# Tracking purity:               0.5632
# ----------
# all steps time----
# 125.84413051605225
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 10.526809930801392
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7453
# Reconstructed tracks:           11709
# Reconstructable tracks Matched: 6747
# Tracking efficiency:            0.9053
# Tracking purity:               0.5762
# ----------
# all steps time----
# 98.56153655052185
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 15.152940511703491
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         9685
# Reconstructed tracks:           15397
# Reconstructable tracks Matched: 8737
# Tracking efficiency:            0.9021
# Tracking purity:               0.5674
# ----------
# all steps time----
# 152.61654210090637
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 11.752191543579102
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7837
# Reconstructed tracks:           12311
# Reconstructable tracks Matched: 7021
# Tracking efficiency:            0.8959
# Tracking purity:               0.5703
# ----------
# all steps time----
# 108.32666945457458
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 11.211426019668579
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7829
# Reconstructed tracks:           12091
# Reconstructable tracks Matched: 7160
# Tracking efficiency:            0.9145
# Tracking purity:               0.5922
# ----------
# all steps time----
# 106.75735378265381
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 14.349415302276611
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8930
# Reconstructed tracks:           14339
# Reconstructable tracks Matched: 8071
# Tracking efficiency:            0.9038
# Tracking purity:               0.5629
# ----------
# all steps time----
# 131.82930088043213
# total time----
# 1136.9493460655212
# --------------------
# ------Noise Level 0.6------
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 10.100727319717407
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7095
# Reconstructed tracks:           11096
# Reconstructable tracks Matched: 6481
# Tracking efficiency:            0.9135
# Tracking purity:               0.5841
# ----------
# all steps time----
# 94.01787781715393
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.430890798568726
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7647
# Reconstructed tracks:           12527
# Reconstructable tracks Matched: 6866
# Tracking efficiency:            0.8979
# Tracking purity:               0.5481
# ----------
# all steps time----
# 111.89079403877258
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.992900133132935
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8471
# Reconstructed tracks:           13555
# Reconstructable tracks Matched: 7646
# Tracking efficiency:            0.9026
# Tracking purity:               0.5641
# ----------
# all steps time----
# 128.93114399909973
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 13.525556087493896
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8545
# Reconstructed tracks:           13780
# Reconstructable tracks Matched: 7730
# Tracking efficiency:            0.9046
# Tracking purity:               0.5610
# ----------
# all steps time----
# 132.83561325073242
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 11.357728242874146
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7453
# Reconstructed tracks:           11938
# Reconstructable tracks Matched: 6710
# Tracking efficiency:            0.9003
# Tracking purity:               0.5621
# ----------
# all steps time----
# 106.35737729072571
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 11.388581991195679
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7344
# Reconstructed tracks:           11436
# Reconstructable tracks Matched: 6709
# Tracking efficiency:            0.9135
# Tracking purity:               0.5867
# ----------
# all steps time----
# 105.42102289199829
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 16.357439756393433
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         9685
# Reconstructed tracks:           15636
# Reconstructable tracks Matched: 8710
# Tracking efficiency:            0.8993
# Tracking purity:               0.5570
# ----------
# all steps time----
# 162.06647491455078
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.405378341674805
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7837
# Reconstructed tracks:           12684
# Reconstructable tracks Matched: 6995
# Tracking efficiency:            0.8926
# Tracking purity:               0.5515
# ----------
# all steps time----
# 116.27775430679321
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.297470331192017
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7829
# Reconstructed tracks:           12215
# Reconstructable tracks Matched: 7133
# Tracking efficiency:            0.9111
# Tracking purity:               0.5840
# ----------
# all steps time----
# 113.91810297966003
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 14.329686641693115
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8930
# Reconstructed tracks:           14567
# Reconstructable tracks Matched: 8028
# Tracking efficiency:            0.8990
# Tracking purity:               0.5511
# ----------
# all steps time----
# 139.8098475933075
# total time----
# 1215.1343097686768
# --------------------
# ------Noise Level 0.8------
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 11.324592113494873
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7095
# Reconstructed tracks:           11270
# Reconstructable tracks Matched: 6451
# Tracking efficiency:            0.9092
# Tracking purity:               0.5724
# ----------
# all steps time----
# 107.89417552947998
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.40937066078186
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7647
# Reconstructed tracks:           12902
# Reconstructable tracks Matched: 6795
# Tracking efficiency:            0.8886
# Tracking purity:               0.5267
# ----------
# all steps time----
# 119.4653639793396
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 14.836851119995117
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8471
# Reconstructed tracks:           13770
# Reconstructable tracks Matched: 7616
# Tracking efficiency:            0.8991
# Tracking purity:               0.5531
# ----------
# all steps time----
# 136.2309639453888
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 14.349402904510498
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8545
# Reconstructed tracks:           14050
# Reconstructable tracks Matched: 7720
# Tracking efficiency:            0.9035
# Tracking purity:               0.5495
# ----------
# all steps time----
# 138.08988666534424
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 11.589986324310303
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7453
# Reconstructed tracks:           12073
# Reconstructable tracks Matched: 6715
# Tracking efficiency:            0.9010
# Tracking purity:               0.5562
# ----------
# all steps time----
# 114.84025120735168
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.3620023727417
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7344
# Reconstructed tracks:           11641
# Reconstructable tracks Matched: 6694
# Tracking efficiency:            0.9115
# Tracking purity:               0.5750
# ----------
# all steps time----
# 112.88359332084656
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 16.739261388778687
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         9685
# Reconstructed tracks:           15874
# Reconstructable tracks Matched: 8679
# Tracking efficiency:            0.8961
# Tracking purity:               0.5467
# ----------
# all steps time----
# 169.20122146606445
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 13.418005466461182
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7837
# Reconstructed tracks:           12689
# Reconstructable tracks Matched: 6997
# Tracking efficiency:            0.8928
# Tracking purity:               0.5514
# ----------
# all steps time----
# 123.4691526889801
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.994550466537476
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7829
# Reconstructed tracks:           12454
# Reconstructable tracks Matched: 7100
# Tracking efficiency:            0.9069
# Tracking purity:               0.5701
# ----------
# all steps time----
# 125.18410658836365
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 15.406511783599854
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8930
# Reconstructed tracks:           14811
# Reconstructable tracks Matched: 8005
# Tracking efficiency:            0.8964
# Tracking purity:               0.5405
# ----------
# all steps time----
# 157.245041847229
# total time----
# 1308.370079278946
# --------------------
# ------Noise Level 1------
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 11.487761974334717
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7095
# Reconstructed tracks:           11463
# Reconstructable tracks Matched: 6447
# Tracking efficiency:            0.9087
# Tracking purity:               0.5624
# ----------
# all steps time----
# 110.97498345375061
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 13.450325012207031
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7647
# Reconstructed tracks:           13181
# Reconstructable tracks Matched: 6783
# Tracking efficiency:            0.8870
# Tracking purity:               0.5146
# ----------
# all steps time----
# 125.52915358543396
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 14.614743947982788
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8471
# Reconstructed tracks:           14044
# Reconstructable tracks Matched: 7597
# Tracking efficiency:            0.8968
# Tracking purity:               0.5409
# ----------
# all steps time----
# 145.54449152946472
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 15.12053370475769
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8545
# Reconstructed tracks:           14422
# Reconstructable tracks Matched: 7675
# Tracking efficiency:            0.8982
# Tracking purity:               0.5322
# ----------
# all steps time----
# 149.65215611457825
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.477774620056152
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7453
# Reconstructed tracks:           12294
# Reconstructable tracks Matched: 6690
# Tracking efficiency:            0.8976
# Tracking purity:               0.5442
# ----------
# all steps time----
# 120.57228755950928
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 12.416558265686035
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7344
# Reconstructed tracks:           11775
# Reconstructable tracks Matched: 6681
# Tracking efficiency:            0.9097
# Tracking purity:               0.5674
# ----------
# all steps time----
# 119.47029042243958
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 17.46254062652588
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         9685
# Reconstructed tracks:           15905
# Reconstructable tracks Matched: 8548
# Tracking efficiency:            0.8826
# Tracking purity:               0.5374
# ----------
# all steps time----
# 180.12184643745422
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 14.11186671257019
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7837
# Reconstructed tracks:           12987
# Reconstructable tracks Matched: 7024
# Tracking efficiency:            0.8963
# Tracking purity:               0.5408
# ----------
# all steps time----
# 138.18179559707642
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 13.402424097061157
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         7829
# Reconstructed tracks:           12599
# Reconstructable tracks Matched: 7077
# Tracking efficiency:            0.9039
# Tracking purity:               0.5617
# ----------
# all steps time----
# 131.41691040992737
#  APPLYING GNN.....
# Loaded -1 checkpoint from /global/cfs/cdirs/m3443/data/lightning_models/gnn
# TRACK LABELLING.....
# build time----
# 15.915946006774902
# ----------
# Processed 0 events from /global/cfs/projectdirs/atlas/xju/heptrkx/trackml_inputs/train_all
# Reconstructable tracks:         8930
# Reconstructed tracks:           14979
# Reconstructable tracks Matched: 7981
# Tracking efficiency:            0.8937
# Tracking purity:               0.5328
# ----------
# all steps time----
# 158.99785208702087
# total time----
# 1384.6685276031494
# --------------------

# %%
# with open('/global/cfs/projectdirs/m3443/usr/caditi97/iml2020/layerless_check/lists_n0.pickle', 'rb') as handle:
#     unpickler = pickle.Unpickler(handle)
#     b = unpickler.load()
# b
# Out:
# {'matched_idx': [array([ True,  True,  True, ...,  True,  True,  True]),
#   array([ True,  True,  True, ...,  True,  True,  True]),
#   array([False,  True,  True, ..., False,  True, False]),
#   array([ True,  True,  True, ...,  True,  True, False]),
#   array([ True,  True,  True, ...,  True,  True, False]),
#   array([ True,  True,  True, ...,  True,  True,  True]),
#   array([False,  True,  True, ...,  True,  True,  True]),
#   array([ True,  True,  True, ...,  True,  True,  True]),
#   array([ True,  True,  True, ...,  True,  True,  True]),
#   array([ True,  True,  True, ...,  True,  True, False])],
#  'peta': [0       1.009692
#   1      -2.667920
#   2      -0.687386
#   3      -0.556053
#   4      -3.270726
#             ...
#   9591    3.458632
#   9593   -0.849981
#   9595    0.280119
#   9596    0.395756
#   9597   -0.337825
#   Length: 7095, dtype: float32,
#   0        2.338404
#   1        0.454788
#   2       -0.220477
#   3        0.398200
#   4       -0.525143
#              ...
#   10534    3.633767
#   10536    2.320711
#   10537    3.528578
#   10538   -1.850995
#   10539   -1.627676
#   Length: 7647, dtype: float32,
#   0        0.039019
#   1        0.224309
#   3        0.122340
#   4       -2.988919
#   5       -3.053298
#              ...
#   11475   -1.718368
#   11476   -1.165897
#   11478   -0.600084
#   11483    0.779803
#   11484    1.865620
#   Length: 8471, dtype: float32,
#   0        3.316722
#   1       -3.639920
#   2       -3.115981
#   3        3.176002
#   4        3.123564
#              ...
#   11523   -2.784780
#   11524   -2.683172
#   11525   -3.548646
#   11527   -1.872155
#   11528    0.195134
#   Length: 8545, dtype: float32,
#   0       -1.662602
#   1        1.297483
#   2       -1.266270
#   3        0.170761
#   4       -0.715631
#              ...
#   10163    2.039477
#   10164    1.505186
#   10165   -3.616803
#   10166   -3.542106
#   10168    1.217696
#   Length: 7453, dtype: float32,
#   0      -2.399276
#   3       3.356397
#   4      -1.555729
#   5      -3.347637
#   6      -2.778194
#             ...
#   9903   -2.743753
#   9904   -1.089808
#   9905   -3.012110
#   9907    1.915945
#   9908    2.221237
#   Length: 7344, dtype: float32,
#   0       -1.002885
#   2       -1.946610
#   3       -2.601840
#   4       -1.058499
#   5        1.383027
#              ...
#   13121    1.584592
#   13123    3.887590
#   13124    2.130196
#   13125    2.172214
#   13126   -1.406960
#   Length: 9685, dtype: float32,
#   0       -1.149144
#   1        2.869268
#   2       -0.217735
#   3        1.660965
#   4        1.643479
#              ...
#   10750    0.172365
#   10751   -0.518016
#   10752    1.822686
#   10755   -3.636188
#   10756    3.338528
#   Length: 7837, dtype: float32,
#   0        1.595376
#   1        2.697605
#   2        2.977681
#   3        0.988966
#   4        0.854814
#              ...
#   10675   -0.507455
#   10678   -1.241659
#   10681    3.459991
#   10682    2.555533
#   10683    1.954424
#   Length: 7829, dtype: float32,
#   0       -1.490466
#   1        2.641643
#   2        2.996505
#   3        2.673073
#   4        2.876069
#              ...
#   12157   -1.891172
#   12158   -2.145652
#   12159   -1.935794
#   12160   -2.031868
#   12162   -2.029969
#   Length: 8930, dtype: float32],
#  'par_pt': [0       19.876463
#   1        0.170793
#   2        1.760097
#   3        1.602067
#   4        0.884181
#             ...
#   9591     0.189276
#   9593     0.157261
#   9595     0.435399
#   9596     0.522767
#   9597     0.325580
#   Length: 7095, dtype: float32,
#   0        4.619218
#   1        8.340401
#   2        0.698699
#   3        2.011146
#   4        1.157198
#              ...
#   10534    0.202919
#   10536    0.226502
#   10537    0.289015
#   10538    0.384811
#   10539    0.408959
#   Length: 7647, dtype: float32,
#   0        34.711853
#   1         0.589620
#   3         0.990783
#   4         0.186678
#   5         1.223004
#              ...
#   11475     0.298640
#   11476     0.335424
#   11478     0.318971
#   11483     0.387671
#   11484     0.161677
#   Length: 8471, dtype: float32,
#   0        0.446253
#   1        1.355333
#   2        1.664203
#   3        1.563564
#   4        1.468401
#              ...
#   11523    0.618263
#   11524    0.320451
#   11525    1.066670
#   11527    0.772948
#   11528    0.354552
#   Length: 8545, dtype: float32,
#   0         0.171727
#   1         0.941039
#   2        28.592453
#   3         2.465257
#   4         1.894804
#              ...
#   10163     1.153755
#   10164     0.198707
#   10165     0.962059
#   10166     0.303952
#   10168     0.233458
#   Length: 7453, dtype: float32,
#   0       0.994643
#   3       0.626837
#   4       0.590891
#   5       0.733256
#   6       1.270727
#             ...
#   9903    0.174236
#   9904    0.669388
#   9905    0.637298
#   9907    0.632558
#   9908    1.097195
#   Length: 7344, dtype: float32,
#   0        18.295893
#   2         0.474724
#   3         0.861622
#   4         0.156544
#   5         0.529845
#              ...
#   13121     0.192406
#   13123     0.306349
#   13124     0.822215
#   13125     0.307416
#   13126     0.297966
#   Length: 9685, dtype: float32,
#   0        55.443752
#   1         1.517528
#   2         0.787628
#   3        12.963695
#   4        15.792516
#              ...
#   10750     0.232303
#   10751     0.634763
#   10752     0.287788
#   10755     0.239335
#   10756     0.285440
#   Length: 7837, dtype: float32,
#   0         0.955753
#   1         1.612937
#   2         0.476128
#   3        62.868095
#   4         6.240671
#              ...
#   10675     0.180682
#   10678     0.241661
#   10681     0.158183
#   10682     0.221520
#   10683     0.344711
#   Length: 7829, dtype: float32,
#   0        24.785429
#   1         0.318989
#   2         2.984797
#   3         3.119117
#   4         4.666247
#              ...
#   12157     0.188586
#   12158     0.427463
#   12159     0.155253
#   12160     0.296349
#   12162     0.481694
#   Length: 8930, dtype: float32],
#  'avg_build_time': [16.654722452163696,
#   9.594406366348267,
#   11.129013538360596,
#   11.10592794418335,
#   9.052181243896484,
#   8.915536880493164,
#   13.933180570602417,
#   9.600262641906738,
#   9.82116436958313,
#   11.946629524230957],
#  'all_steps': [89.20351719856262,
#   96.75229525566101,
#   107.81333518028259,
#   107.35285878181458,
#   91.60831904411316,
#   84.69410586357117,
#   140.03948831558228,
#   94.66657185554504,
#   101.2691547870636,
#   120.20058059692383],
#  'esp_times': [51.06037616729736,
#   59.136056423187256,
#   64.21828746795654,
#   63.97421407699585,
#   56.542521476745605,
#   49.41776752471924,
#   84.0493552684784,
#   54.42135715484619,
#   62.579946756362915,
#   72.11525416374207],
#  'f_times': [20.98748540878296,
#   27.50777578353882,
#   31.907407522201538,
#   31.708022594451904,
#   25.46057367324829,
#   25.809977769851685,
#   41.43225383758545,
#   30.082454681396484,
#   28.34992551803589,
#   35.55439877510071],
#  'trkeff_times': [0.5007338523864746,
#   0.5138607025146484,
#   0.5581140518188477,
#   0.5645115375518799,
#   0.5528693199157715,
#   0.5506749153137207,
#   0.6245260238647461,
#   0.5618107318878174,
#   0.5179438591003418,
#   0.5840954780578613],
#  'total_time': 1036.4128665924072}

# %%
# make_cmp_plot_fn = partial(make_cmp_plot, xlegend="Matched", ylegend="Reconstructable",
#                     ylabel="Events", ratio_label='Track efficiency')

# %%
# make_cmp_plot_fn(par_pt[matched_idx], par_pt,
#                  configs=pt_configs,
#                  xlabel="pT [GeV]",
#                  outname=os.path.join(plots_dir, "{}_pt".format('1000')))

# %%
# make_cmp_plot_fn(peta[matched_idx], peta,
#                  configs=eta_configs,
#                  xlabel=r"$\eta$",
#                  outname=os.path.join(plots_dir, "{}_eta".format('1000')))
